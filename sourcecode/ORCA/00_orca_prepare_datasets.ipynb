# %% [markdown]
# # Extracts the image-patches dataset

# %%
from orca_dataloader import *

magnification=0.625
scale = get_scale_by_magnification(magnification)
tile_size=20
tile_size_original = int(scale * tile_size)


cls = "tumor"
dataset_types = ["training", "testing"]
for dataset_type in sorted(dataset_types):
    
    logger.info("{} images".format(dataset_type))
    
    orca_dir = "../../datasets/ORCA"
    annotations_dir = "{}/{}/lesion_annotations".format(orca_dir, dataset_type)
    wsi_images_dir = "{}/{}/{}/wsi".format(orca_dir, dataset_type, cls)
    patch_images_dir = "{}/{}/{}/patch/640x640".format(orca_dir, dataset_type, cls)
    
    for r, d, f in sorted(os.walk(wsi_images_dir)):
        for wsi_file in sorted(f):
            
            wsi_image_file = "{}/{}".format(r, wsi_file)
            wsi_image_number = wsi_file.replace(".png", "")
            
            file_is_png = wsi_image_file.lower().endswith('.png')
            if file_is_png:

                logger.info("Processing tma '{}'".format(wsi_file))
                
                # check directory to save image-patches
                dir_to_save = "{}/{}".format(patch_images_dir, wsi_image_number)
                if not os.path.exists(dir_to_save):
                    os.makedirs("{}/01-roi/01-original".format(dir_to_save))
                    os.makedirs("{}/01-roi/02-mask".format(dir_to_save))
                    os.makedirs("{}/01-roi/03-roi".format(dir_to_save))             
                    os.makedirs("{}/02-non_roi/01-original".format(dir_to_save))
                    os.makedirs("{}/02-non_roi/02-mask".format(dir_to_save))
                
                # tumor annotations mask
                annotation_file = "{}/{}_mask.png".format(annotations_dir, wsi_image_number)
                wsi_mask_pil = load_pil_image(annotation_file, gray=True)
                
                # tumor tissue region
                wsi_image = open_wsi(wsi_image_file)
                max_w, max_h = wsi_image.dimensions
                wsi_image_pil = load_pil_image(wsi_image_file, gray=False)
                pil_scaled_down_image = scale_down_wsi(wsi_image, magnification, False)
                
                np_tumor_mask = np.zeros((wsi_mask_pil.size[0], wsi_mask_pil.size[1]), dtype=bool)
                np_tumor_mask[pil_to_np(wsi_mask_pil) == 255] = True
                pil_tumor_mask = np_to_pil(np_tumor_mask)
                
                np_normal_mask = np.zeros((wsi_mask_pil.size[0], wsi_mask_pil.size[1]), dtype=bool)
                np_normal_mask[pil_to_np(wsi_mask_pil) < 255] = True
                np_normal_mask[pil_to_np(wsi_mask_pil) == 0] = False
                pil_normal_mask = np_to_pil(np_normal_mask)
                
                pil_background = np_to_pil(np_normal_mask | np_tumor_mask)

                wsi_image_np = pil_to_np(wsi_image_pil)
                np_tumor_masked = mask_rgb(wsi_image_np, np_tumor_mask)
                np_tumor_masked = image_resize(np_tumor_masked, height=pil_scaled_down_image.size[1])
                pil_tumor_masked = np_to_pil(np_tumor_masked)
                
                np_normal_masked = mask_rgb(wsi_image_np, np_normal_mask)
                np_normal_masked = image_resize(np_normal_masked, height=pil_scaled_down_image.size[1])
                pil_normal_masked = np_to_pil(np_normal_masked)

                blend_tumor = blend_image(wsi_image_pil, pil_tumor_mask, foreground='red', inverse=True)
                blend_tissue = blend_image(blend_tumor, pil_normal_mask, foreground='green', inverse=True)
                # https://pillow.readthedocs.io/en/stable/releasenotes/10.0.0.html#constants
                blend_background = blend_image(blend_tissue, pil_background, foreground='blue', inverse=False).resize(pil_tumor_masked.size, Image.LANCZOS)

                pil_scaled_down_image.save('{}/{}_1.png'.format(dir_to_save, wsi_image_number))
                blend_background.save('{}/{}_2.png'.format(dir_to_save, wsi_image_number))
                pil_normal_masked.save('{}/{}_3.png'.format(dir_to_save, wsi_image_number))
                pil_tumor_masked.save('{}/{}_4.png'.format(dir_to_save, wsi_image_number))
                
                #heat grid normal
                pil_img_normal_result, heat_grid_normal, number_of_tiles_normal = draw_heat_grid(np_normal_masked, tile_size)
                pil_img_normal_result.save('{}/{}_5.png'.format(dir_to_save, wsi_image_number))

                # heat grid tumor
                pil_img_result, heat_grid, number_of_tiles = draw_heat_grid(np_tumor_masked, tile_size)
                pil_img_result.save('{}/{}_6.png'.format(dir_to_save, wsi_image_number))
                
                used_patches = set()                
                tiles_tumor_tissue = []
                tiles_normal_tissue = []
                tiles_background = []
                for idx, (position, row, column, location, size, color) in enumerate(heat_grid):

                    tile = (position, row, column, location, size, color)                    
                    if color == YELLOW_COLOR or color == ORANGE_COLOR or color == RED_COLOR:
                        tiles_tumor_tissue.append(tile)
                        used_patches.add("r{}c{}".format(row, column))
                
                for idx, (position, row, column, location, size, color) in enumerate(heat_grid_normal):

                    name = "r{}c{}".format(row, column)
                    tile = (position, row, column, location, size, color)
                    if name not in used_patches:
                        if color == GREEN_COLOR:
                            tiles_background.append(tile)
                        else:
                            tiles_normal_tissue.append(tile)
                
                logger.info("\t {} patches of 640x640 size.".format(len(heat_grid_normal)))
                logger.info("\t\t {} patches of 640x640 (normal tissue).".format(len(tiles_normal_tissue)))
                logger.info("\t\t {} patches of 640x640 (tumor tissue).".format(len(tiles_tumor_tissue)))
                logger.info("\t\t {} patches of 640x640 (background).".format(len(tiles_background)))
                
                
                # extract and save normal patches
                for (position, row, column, location, size, color) in tiles_normal_tissue:
                    
                    r_s = row * tile_size_original
                    r_e = r_s + (tile_size_original if (r_s + tile_size_original) <= max_w else (max_w - r_s))
                    c_s = column * tile_size_original
                    c_e = c_s + (tile_size_original if (c_s + tile_size_original) <= max_h else (max_h - c_s))
                    
                    np_tile_mask = np.zeros((tile_size_original, tile_size_original), dtype=bool)
                    np_tile_mask[0:(r_e-r_s), 0:(c_e-c_s)] = np_tumor_mask[r_s:r_e, c_s:c_e]
                    
                    # only tile with valid size
                    #if np_tile_mask.shape[0] == tile_size_original and np_tile_mask.shape[1] == tile_size_original:

                    tile_pil, tile_np = read_region(wsi_image_file, column, row, magnification, tile_size)
                    left = (column * tile_size_original)
                    top = (row * tile_size_original)

                    pil_mask = np_to_pil(np.zeros((tile_np.shape[0], tile_np.shape[1]), dtype=np.uint8))
                    np_tile_mask = pil_to_np(pil_mask).astype(bool)

                    # save the extracted normal tile
                    tile_pil.save('{}/02-non_roi/{}/{}_r{}c{}.png'.format(dir_to_save, "01-original", wsi_image_number, row, column))
                    np_to_pil(np_tile_mask).save('{}/02-non_roi/{}/{}_r{}c{}.png'.format(dir_to_save, "02-mask", wsi_image_number, row, column))

                # extract and save tumor patches
                for (position, row, column, location, size, color) in tiles_tumor_tissue:
                    
                    r_s = row * tile_size_original
                    r_e = r_s + (tile_size_original if (r_s + tile_size_original) <= max_w else (max_w - r_s))
                    c_s = column * tile_size_original
                    c_e = c_s + (tile_size_original if (c_s + tile_size_original) <= max_h else (max_h - c_s))
                    
                    np_tile_mask = np.zeros((tile_size_original, tile_size_original), dtype=bool)
                    np_tile_mask[0:(r_e-r_s), 0:(c_e-c_s)] = np_tumor_mask[r_s:r_e, c_s:c_e]
                    
                    # only tile with valid size
                    #if np_tile_mask.shape[0] == tile_size_original and np_tile_mask.shape[1] == tile_size_original:

                    tile_pil, tile_np = read_region(wsi_image_file, column, row, magnification, tile_size)
                    left = (column * tile_size_original)
                    top = (row * tile_size_original)
                    
                    pil_tile_roi = blend_image(np_to_pil(tile_np), np_to_pil(np_tile_mask), foreground='blue', inverse=True)
                    #pil_tile_roi = blend_image(pil_tile_roi, np_to_pil(np_tile_mask), foreground='green', inverse=False)

                     # save the extracted tumor image-patch
                    tile_pil.save('{}/01-roi/{}/{}_r{}c{}.png'.format(dir_to_save, "01-original", wsi_image_number, row, column))
                    np_to_pil(np_tile_mask).save('{}/01-roi/{}/{}_r{}c{}.png'.format(dir_to_save, "02-mask", wsi_image_number, row, column))
                    pil_tile_roi.save('{}/01-roi/{}/{}_r{}c{}.png'.format(dir_to_save, "03-roi", wsi_image_number, row, column))
# Out:
# 2023-08-22 14:28:57,707 :: INFO <module> :: testing images
# 2023-08-22 14:28:57,709 :: INFO <module> :: Processing tma 'TCGA-CN-4723-01Z-00-DX1.13483e7b-9322-4d39-8cd6-91e898bf2ee9_0.png'
# 2023-08-22 14:29:01,807 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:29:01,808 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 14:29:01,809 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 14:29:01,810 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:29:40,975 :: INFO <module> :: Processing tma 'TCGA-CN-4723-01Z-00-DX1.13483e7b-9322-4d39-8cd6-91e898bf2ee9_1.png'
# 2023-08-22 14:29:44,658 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:29:44,659 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 14:29:44,660 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 14:29:44,661 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:30:27,311 :: INFO <module> :: Processing tma 'TCGA-CN-4725-01Z-00-DX1.fe518acf-cceb-4be4-b01a-63d66248d6d4_0.png'
# 2023-08-22 14:30:31,219 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:30:31,220 :: INFO <module> :: 		 6 patches of 640x640 (normal tissue).
# 2023-08-22 14:30:31,222 :: INFO <module> :: 		 39 patches of 640x640 (tumor tissue).
# 2023-08-22 14:30:31,225 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:31:15,071 :: INFO <module> :: Processing tma 'TCGA-CN-4725-01Z-00-DX1.fe518acf-cceb-4be4-b01a-63d66248d6d4_1.png'
# 2023-08-22 14:31:18,873 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:31:18,874 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 14:31:18,875 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 14:31:18,876 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:32:03,274 :: INFO <module> :: Processing tma 'TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_0.png'
# 2023-08-22 14:32:07,410 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:32:07,411 :: INFO <module> :: 		 1 patches of 640x640 (normal tissue).
# 2023-08-22 14:32:07,412 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 14:32:07,413 :: INFO <module> :: 		 5 patches of 640x640 (background).
# 2023-08-22 14:32:46,083 :: INFO <module> :: Processing tma 'TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_1.png'
# 2023-08-22 14:32:49,506 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:32:49,507 :: INFO <module> :: 		 1 patches of 640x640 (normal tissue).
# 2023-08-22 14:32:49,508 :: INFO <module> :: 		 44 patches of 640x640 (tumor tissue).
# 2023-08-22 14:32:49,509 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:33:35,205 :: INFO <module> :: Processing tma 'TCGA-CN-4727-01Z-00-DX1.bee9d488-0f05-4579-8c34-aa4197972bb1_0.png'
# 2023-08-22 14:33:39,898 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:33:39,899 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 14:33:39,901 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 14:33:39,903 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:34:30,498 :: INFO <module> :: Processing tma 'TCGA-CN-4727-01Z-00-DX1.bee9d488-0f05-4579-8c34-aa4197972bb1_1.png'
# 2023-08-22 14:34:35,123 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:34:35,124 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 14:34:35,124 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 14:34:35,126 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:35:24,661 :: INFO <module> :: Processing tma 'TCGA-CN-4728-01Z-00-DX1.69fc04ce-cc6b-4c63-9322-b5ffb0056828_0.png'
# 2023-08-22 14:35:29,290 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:35:29,291 :: INFO <module> :: 		 16 patches of 640x640 (normal tissue).
# 2023-08-22 14:35:29,292 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-08-22 14:35:29,293 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:36:19,128 :: INFO <module> :: Processing tma 'TCGA-CN-4728-01Z-00-DX1.69fc04ce-cc6b-4c63-9322-b5ffb0056828_1.png'
# 2023-08-22 14:36:23,750 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:36:23,751 :: INFO <module> :: 		 20 patches of 640x640 (normal tissue).
# 2023-08-22 14:36:23,752 :: INFO <module> :: 		 25 patches of 640x640 (tumor tissue).
# 2023-08-22 14:36:23,754 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:37:13,235 :: INFO <module> :: Processing tma 'TCGA-CN-4729-01Z-00-DX1.fd5f9170-c35b-4095-aff3-4c95921e0e68_0.png'
# 2023-08-22 14:37:16,610 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:37:16,611 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 14:37:16,612 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 14:37:16,613 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:37:59,908 :: INFO <module> :: Processing tma 'TCGA-CN-4729-01Z-00-DX1.fd5f9170-c35b-4095-aff3-4c95921e0e68_1.png'
# 2023-08-22 14:38:03,496 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:38:03,497 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 14:38:03,498 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 14:38:03,498 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:38:44,589 :: INFO <module> :: Processing tma 'TCGA-CN-4730-01Z-00-DX1.a76280e8-6591-4d51-afc9-2f01e87346ab_0.png'
# 2023-08-22 14:38:48,308 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:38:48,310 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 14:38:48,311 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-08-22 14:38:48,313 :: INFO <module> :: 		 13 patches of 640x640 (background).
# 2023-08-22 14:39:17,363 :: INFO <module> :: Processing tma 'TCGA-CN-4730-01Z-00-DX1.a76280e8-6591-4d51-afc9-2f01e87346ab_1.png'
# 2023-08-22 14:39:21,043 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:39:21,044 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 14:39:21,045 :: INFO <module> :: 		 23 patches of 640x640 (tumor tissue).
# 2023-08-22 14:39:21,046 :: INFO <module> :: 		 13 patches of 640x640 (background).
# 2023-08-22 14:39:50,164 :: INFO <module> :: Processing tma 'TCGA-CN-4731-01Z-00-DX1.07b0bf3b-77f3-4471-a63c-1afc54714a60_0.png'
# 2023-08-22 14:39:54,256 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:39:54,257 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 14:39:54,259 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 14:39:54,260 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:40:36,131 :: INFO <module> :: Processing tma 'TCGA-CN-4731-01Z-00-DX1.07b0bf3b-77f3-4471-a63c-1afc54714a60_1.png'
# 2023-08-22 14:40:40,524 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:40:40,525 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 14:40:40,526 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 14:40:40,526 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:41:20,588 :: INFO <module> :: Processing tma 'TCGA-CN-4733-01Z-00-DX1.03cccb3f-c551-450f-b00a-f808a237db0b_0.png'
# 2023-08-22 14:41:23,651 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:41:23,652 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 14:41:23,653 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 14:41:23,654 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:42:04,566 :: INFO <module> :: Processing tma 'TCGA-CN-4733-01Z-00-DX1.03cccb3f-c551-450f-b00a-f808a237db0b_1.png'
# 2023-08-22 14:42:08,747 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:42:08,748 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 14:42:08,749 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 14:42:08,750 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:42:52,940 :: INFO <module> :: Processing tma 'TCGA-CN-4734-01Z-00-DX1.9cd35e43-7132-478a-9d08-a88d150b7127_0.png'
# 2023-08-22 14:42:56,840 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:42:56,841 :: INFO <module> :: 		 1 patches of 640x640 (normal tissue).
# 2023-08-22 14:42:56,841 :: INFO <module> :: 		 44 patches of 640x640 (tumor tissue).
# 2023-08-22 14:42:56,843 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:43:39,218 :: INFO <module> :: Processing tma 'TCGA-CN-4734-01Z-00-DX1.9cd35e43-7132-478a-9d08-a88d150b7127_1.png'
# 2023-08-22 14:43:43,902 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:43:43,903 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 14:43:43,904 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 14:43:43,905 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:44:25,985 :: INFO <module> :: Processing tma 'TCGA-CN-4735-01Z-00-DX1.b7d37666-bd65-4d3b-826b-97e560444956_0.png'
# 2023-08-22 14:44:29,822 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:44:29,825 :: INFO <module> :: 		 16 patches of 640x640 (normal tissue).
# 2023-08-22 14:44:29,827 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-08-22 14:44:29,828 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:45:07,491 :: INFO <module> :: Processing tma 'TCGA-CN-4735-01Z-00-DX1.b7d37666-bd65-4d3b-826b-97e560444956_1.png'
# 2023-08-22 14:45:11,545 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:45:11,546 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 14:45:11,548 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 14:45:11,549 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:45:51,824 :: INFO <module> :: Processing tma 'TCGA-CN-4736-01Z-00-DX1.883fda2c-82bd-46c1-b220-b9961d8700cc_0.png'
# 2023-08-22 14:45:55,432 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:45:55,433 :: INFO <module> :: 		 1 patches of 640x640 (normal tissue).
# 2023-08-22 14:45:55,436 :: INFO <module> :: 		 44 patches of 640x640 (tumor tissue).
# 2023-08-22 14:45:55,437 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:46:38,273 :: INFO <module> :: Processing tma 'TCGA-CN-4736-01Z-00-DX1.883fda2c-82bd-46c1-b220-b9961d8700cc_1.png'
# 2023-08-22 14:46:41,998 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:46:41,999 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 14:46:42,000 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 14:46:42,003 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:47:24,098 :: INFO <module> :: Processing tma 'TCGA-CN-4737-01Z-00-DX1.15951662-62c1-49e1-94ea-1f4ebad55507_0.png'
# 2023-08-22 14:47:28,420 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:47:28,421 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 14:47:28,422 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 14:47:28,423 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:48:07,523 :: INFO <module> :: Processing tma 'TCGA-CN-4737-01Z-00-DX1.15951662-62c1-49e1-94ea-1f4ebad55507_1.png'
# 2023-08-22 14:48:11,095 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:48:11,096 :: INFO <module> :: 		 17 patches of 640x640 (normal tissue).
# 2023-08-22 14:48:11,097 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-08-22 14:48:11,099 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:48:49,905 :: INFO <module> :: Processing tma 'TCGA-CN-4738-01Z-00-DX1.9c456d54-0bde-4f04-ba53-17c09e692491_0.png'
# 2023-08-22 14:48:53,490 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:48:53,491 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 14:48:53,492 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 14:48:53,493 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:49:34,640 :: INFO <module> :: Processing tma 'TCGA-CN-4738-01Z-00-DX1.9c456d54-0bde-4f04-ba53-17c09e692491_1.png'
# 2023-08-22 14:49:38,521 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:49:38,521 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 14:49:38,522 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 14:49:38,523 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:50:19,428 :: INFO <module> :: Processing tma 'TCGA-CN-4739-01Z-00-DX1.e50266c3-606e-4103-a029-021246d4d1df_0.png'
# 2023-08-22 14:50:23,747 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:50:23,749 :: INFO <module> :: 		 14 patches of 640x640 (normal tissue).
# 2023-08-22 14:50:23,751 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-08-22 14:50:23,752 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:51:03,082 :: INFO <module> :: Processing tma 'TCGA-CN-4739-01Z-00-DX1.e50266c3-606e-4103-a029-021246d4d1df_1.png'
# 2023-08-22 14:51:06,810 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:51:06,811 :: INFO <module> :: 		 14 patches of 640x640 (normal tissue).
# 2023-08-22 14:51:06,812 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-08-22 14:51:06,813 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:51:45,361 :: INFO <module> :: Processing tma 'TCGA-CN-4740-01Z-00-DX1.f7b9f5ec-cb4e-4604-9d64-2bdc20ac5bec_0.png'
# 2023-08-22 14:51:49,353 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:51:49,354 :: INFO <module> :: 		 14 patches of 640x640 (normal tissue).
# 2023-08-22 14:51:49,355 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-08-22 14:51:49,356 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:52:29,540 :: INFO <module> :: Processing tma 'TCGA-CN-4740-01Z-00-DX1.f7b9f5ec-cb4e-4604-9d64-2bdc20ac5bec_1.png'
# 2023-08-22 14:52:33,191 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:52:33,191 :: INFO <module> :: 		 19 patches of 640x640 (normal tissue).
# 2023-08-22 14:52:33,192 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-08-22 14:52:33,193 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:53:11,951 :: INFO <module> :: Processing tma 'TCGA-CN-4741-01Z-00-DX1.6adfce37-b5b0-44ff-834e-85059eec24c0_0.png'
# 2023-08-22 14:53:15,584 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:53:15,586 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 14:53:15,587 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 14:53:15,589 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:53:55,493 :: INFO <module> :: Processing tma 'TCGA-CN-4741-01Z-00-DX1.6adfce37-b5b0-44ff-834e-85059eec24c0_1.png'
# 2023-08-22 14:53:59,280 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:53:59,281 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 14:53:59,281 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 14:53:59,282 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:54:40,219 :: INFO <module> :: Processing tma 'TCGA-CN-4742-01Z-00-DX1.d03eaeac-cc05-4b13-962e-d4d10617d692_0.png'
# 2023-08-22 14:54:44,036 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:54:44,037 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 14:54:44,038 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 14:54:44,039 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:55:23,918 :: INFO <module> :: Processing tma 'TCGA-CN-4742-01Z-00-DX1.d03eaeac-cc05-4b13-962e-d4d10617d692_1.png'
# 2023-08-22 14:55:27,528 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:55:27,528 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 14:55:27,529 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 14:55:27,530 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:56:07,735 :: INFO <module> :: Processing tma 'TCGA-CN-5355-01Z-00-DX1.8fb23e44-fc59-4191-b825-cc021807a338_0.png'
# 2023-08-22 14:56:11,592 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:56:11,594 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 14:56:11,596 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 14:56:11,597 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:56:52,021 :: INFO <module> :: Processing tma 'TCGA-CN-5355-01Z-00-DX1.8fb23e44-fc59-4191-b825-cc021807a338_1.png'
# 2023-08-22 14:56:55,874 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:56:55,874 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 14:56:55,875 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 14:56:55,876 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:57:36,363 :: INFO <module> :: Processing tma 'TCGA-CN-5356-01Z-00-DX1.53360c41-d0d2-465e-8b53-ccd1a2ce248f_0.png'
# 2023-08-22 14:57:40,238 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:57:40,239 :: INFO <module> :: 		 15 patches of 640x640 (normal tissue).
# 2023-08-22 14:57:40,240 :: INFO <module> :: 		 30 patches of 640x640 (tumor tissue).
# 2023-08-22 14:57:40,240 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:58:19,524 :: INFO <module> :: Processing tma 'TCGA-CN-5356-01Z-00-DX1.53360c41-d0d2-465e-8b53-ccd1a2ce248f_1.png'
# 2023-08-22 14:58:23,134 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:58:23,135 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 14:58:23,136 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 14:58:23,137 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:59:03,121 :: INFO <module> :: Processing tma 'TCGA-CN-5358-01Z-00-DX1.6554cdc1-7d01-4310-a60a-79b8ed7a8679_0.png'
# 2023-08-22 14:59:06,833 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:59:06,833 :: INFO <module> :: 		 1 patches of 640x640 (normal tissue).
# 2023-08-22 14:59:06,834 :: INFO <module> :: 		 44 patches of 640x640 (tumor tissue).
# 2023-08-22 14:59:06,835 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 14:59:48,644 :: INFO <module> :: Processing tma 'TCGA-CN-5358-01Z-00-DX1.6554cdc1-7d01-4310-a60a-79b8ed7a8679_1.png'
# 2023-08-22 14:59:52,170 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 14:59:52,171 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 14:59:52,172 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 14:59:52,173 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:00:33,437 :: INFO <module> :: Processing tma 'TCGA-CN-5359-01Z-00-DX1.30a19cad-c2b0-4c5f-bd5d-89aa8ac2bb91_0.png'
# 2023-08-22 15:00:37,578 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:00:37,579 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 15:00:37,580 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 15:00:37,581 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:01:18,306 :: INFO <module> :: Processing tma 'TCGA-CN-5359-01Z-00-DX1.30a19cad-c2b0-4c5f-bd5d-89aa8ac2bb91_1.png'
# 2023-08-22 15:01:22,052 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:01:22,054 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 15:01:22,056 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 15:01:22,058 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:02:02,153 :: INFO <module> :: Processing tma 'TCGA-CN-5360-01Z-00-DX1.d3657b07-9ea0-41fc-b858-c9a1497340c8_0.png'
# 2023-08-22 15:02:05,650 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:02:05,651 :: INFO <module> :: 		 21 patches of 640x640 (normal tissue).
# 2023-08-22 15:02:05,652 :: INFO <module> :: 		 24 patches of 640x640 (tumor tissue).
# 2023-08-22 15:02:05,652 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:02:44,612 :: INFO <module> :: Processing tma 'TCGA-CN-5360-01Z-00-DX1.d3657b07-9ea0-41fc-b858-c9a1497340c8_1.png'
# 2023-08-22 15:02:48,398 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:02:48,398 :: INFO <module> :: 		 22 patches of 640x640 (normal tissue).
# 2023-08-22 15:02:48,399 :: INFO <module> :: 		 23 patches of 640x640 (tumor tissue).
# 2023-08-22 15:02:48,400 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:03:25,790 :: INFO <module> :: Processing tma 'TCGA-CN-5361-01Z-00-DX1.719cf77b-0dd4-4419-be8f-0d3dadedd7cb_0.png'
# 2023-08-22 15:03:29,279 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:03:29,281 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-08-22 15:03:29,282 :: INFO <module> :: 		 45 patches of 640x640 (tumor tissue).
# 2023-08-22 15:03:29,283 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:04:09,129 :: INFO <module> :: Processing tma 'TCGA-CN-5361-01Z-00-DX1.719cf77b-0dd4-4419-be8f-0d3dadedd7cb_1.png'
# 2023-08-22 15:04:15,704 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:04:15,706 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 15:04:15,713 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 15:04:15,719 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:05:08,398 :: INFO <module> :: Processing tma 'TCGA-CN-5363-01Z-00-DX1.bd9c87d4-de64-4932-a90f-95888150d780_0.png'
# 2023-08-22 15:05:12,140 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:05:12,141 :: INFO <module> :: 		 19 patches of 640x640 (normal tissue).
# 2023-08-22 15:05:12,142 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-08-22 15:05:12,144 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:05:50,144 :: INFO <module> :: Processing tma 'TCGA-CN-5363-01Z-00-DX1.bd9c87d4-de64-4932-a90f-95888150d780_1.png'
# 2023-08-22 15:05:53,749 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:05:53,750 :: INFO <module> :: 		 15 patches of 640x640 (normal tissue).
# 2023-08-22 15:05:53,752 :: INFO <module> :: 		 30 patches of 640x640 (tumor tissue).
# 2023-08-22 15:05:53,752 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:06:32,190 :: INFO <module> :: Processing tma 'TCGA-CN-5364-01Z-00-DX1.caeed5d0-cd48-40f3-b81b-099637341563_0.png'
# 2023-08-22 15:06:37,441 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:06:37,443 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 15:06:37,444 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 15:06:37,446 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:07:18,222 :: INFO <module> :: Processing tma 'TCGA-CN-5364-01Z-00-DX1.caeed5d0-cd48-40f3-b81b-099637341563_1.png'
# 2023-08-22 15:07:22,406 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:07:22,407 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 15:07:22,408 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 15:07:22,409 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:07:58,127 :: INFO <module> :: Processing tma 'TCGA-CN-5365-01Z-00-DX1.26a33bd0-1eb3-4774-8be6-bf8501f4a9f9_0.png'
# 2023-08-22 15:08:01,264 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:08:01,264 :: INFO <module> :: 		 12 patches of 640x640 (normal tissue).
# 2023-08-22 15:08:01,265 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-08-22 15:08:01,266 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:08:37,564 :: INFO <module> :: Processing tma 'TCGA-CN-5365-01Z-00-DX1.26a33bd0-1eb3-4774-8be6-bf8501f4a9f9_1.png'
# 2023-08-22 15:08:41,042 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:08:41,043 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 15:08:41,044 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 15:08:41,044 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:09:16,387 :: INFO <module> :: Processing tma 'TCGA-CN-5366-01Z-00-DX1.dcc14c44-6dd1-48a1-a21c-736c6b9551e1_0.png'
# 2023-08-22 15:09:19,751 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:09:19,752 :: INFO <module> :: 		 7 patches of 640x640 (normal tissue).
# 2023-08-22 15:09:19,753 :: INFO <module> :: 		 38 patches of 640x640 (tumor tissue).
# 2023-08-22 15:09:19,754 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:09:58,556 :: INFO <module> :: Processing tma 'TCGA-CN-5366-01Z-00-DX1.dcc14c44-6dd1-48a1-a21c-736c6b9551e1_1.png'
# 2023-08-22 15:10:02,181 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:10:02,182 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 15:10:02,183 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 15:10:02,184 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:10:40,619 :: INFO <module> :: Processing tma 'TCGA-CN-5367-01Z-00-DX1.5b09e54e-4140-4709-bc60-e201f9a72b24_0.png'
# 2023-08-22 15:10:43,979 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:10:43,980 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 15:10:43,981 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 15:10:43,982 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:11:19,624 :: INFO <module> :: Processing tma 'TCGA-CN-5367-01Z-00-DX1.5b09e54e-4140-4709-bc60-e201f9a72b24_1.png'
# 2023-08-22 15:11:22,694 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:11:22,695 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 15:11:22,695 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 15:11:22,696 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:11:59,059 :: INFO <module> :: Processing tma 'TCGA-CN-5369-01Z-00-DX1.be289b39-c6c2-43a6-8feb-75ad5829ec81_0.png'
# 2023-08-22 15:12:02,272 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:12:02,273 :: INFO <module> :: 		 17 patches of 640x640 (normal tissue).
# 2023-08-22 15:12:02,274 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-08-22 15:12:02,274 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:12:46,770 :: INFO <module> :: Processing tma 'TCGA-CN-5369-01Z-00-DX1.be289b39-c6c2-43a6-8feb-75ad5829ec81_1.png'
# 2023-08-22 15:12:50,571 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:12:50,573 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 15:12:50,574 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 15:12:50,577 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:13:36,298 :: INFO <module> :: Processing tma 'TCGA-CN-5373-01Z-00-DX1.c423a74f-cdb6-41b1-9483-be854827434e_0.png'
# 2023-08-22 15:13:39,543 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:13:39,544 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 15:13:39,545 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 15:13:39,546 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:14:21,709 :: INFO <module> :: Processing tma 'TCGA-CN-5373-01Z-00-DX1.c423a74f-cdb6-41b1-9483-be854827434e_1.png'
# 2023-08-22 15:14:25,292 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:14:25,294 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 15:14:25,295 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 15:14:25,295 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:15:06,243 :: INFO <module> :: Processing tma 'TCGA-CN-5374-01Z-00-DX1.027c681b-d8d8-47fd-b0f8-917d6ddb3b83_0.png'
# 2023-08-22 15:15:09,415 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:15:09,416 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 15:15:09,418 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 15:15:09,418 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:15:46,428 :: INFO <module> :: Processing tma 'TCGA-CN-5374-01Z-00-DX1.027c681b-d8d8-47fd-b0f8-917d6ddb3b83_1.png'
# 2023-08-22 15:15:49,551 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:15:49,552 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 15:15:49,553 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 15:15:49,554 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:16:25,719 :: INFO <module> :: Processing tma 'TCGA-CN-6010-01Z-00-DX1.8a82a2d0-c687-4b75-922f-b5b64b5a99df_0.png'
# 2023-08-22 15:16:29,043 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:16:29,044 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 15:16:29,045 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 15:16:29,046 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:17:06,427 :: INFO <module> :: Processing tma 'TCGA-CN-6010-01Z-00-DX1.8a82a2d0-c687-4b75-922f-b5b64b5a99df_1.png'
# 2023-08-22 15:17:09,656 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:17:09,657 :: INFO <module> :: 		 6 patches of 640x640 (normal tissue).
# 2023-08-22 15:17:09,658 :: INFO <module> :: 		 39 patches of 640x640 (tumor tissue).
# 2023-08-22 15:17:09,659 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:17:50,806 :: INFO <module> :: Processing tma 'TCGA-CN-6011-01Z-00-DX1.a3a73ffe-06b8-42ea-820b-9c2824d96585_0.png'
# 2023-08-22 15:17:54,667 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:17:54,668 :: INFO <module> :: 		 17 patches of 640x640 (normal tissue).
# 2023-08-22 15:17:54,669 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-08-22 15:17:54,669 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:18:33,314 :: INFO <module> :: Processing tma 'TCGA-CN-6011-01Z-00-DX1.a3a73ffe-06b8-42ea-820b-9c2824d96585_1.png'
# 2023-08-22 15:18:37,024 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:18:37,025 :: INFO <module> :: 		 21 patches of 640x640 (normal tissue).
# 2023-08-22 15:18:37,026 :: INFO <module> :: 		 24 patches of 640x640 (tumor tissue).
# 2023-08-22 15:18:37,027 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:19:15,369 :: INFO <module> :: Processing tma 'TCGA-CN-6012-01Z-00-DX1.bd9283bb-47c7-41ab-996a-f3f5070cfc73_0.png'
# 2023-08-22 15:19:19,041 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:19:19,042 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 15:19:19,043 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 15:19:19,044 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:20:00,473 :: INFO <module> :: Processing tma 'TCGA-CN-6012-01Z-00-DX1.bd9283bb-47c7-41ab-996a-f3f5070cfc73_1.png'
# 2023-08-22 15:20:05,700 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:20:05,701 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 15:20:05,702 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 15:20:05,702 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:20:46,666 :: INFO <module> :: Processing tma 'TCGA-CN-6016-01Z-00-DX1.737054ae-50f4-42c4-b79c-c462220b12f3_0.png'
# 2023-08-22 15:20:49,966 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:20:49,967 :: INFO <module> :: 		 15 patches of 640x640 (normal tissue).
# 2023-08-22 15:20:49,968 :: INFO <module> :: 		 30 patches of 640x640 (tumor tissue).
# 2023-08-22 15:20:49,969 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:21:25,699 :: INFO <module> :: Processing tma 'TCGA-CN-6016-01Z-00-DX1.737054ae-50f4-42c4-b79c-c462220b12f3_1.png'
# 2023-08-22 15:21:28,916 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:21:28,917 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 15:21:28,918 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 15:21:28,919 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:22:03,752 :: INFO <module> :: Processing tma 'TCGA-CN-6017-01Z-00-DX1.690fa1af-4b51-41c8-a52d-bd1341f990e9_0.png'
# 2023-08-22 15:22:06,929 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:22:06,930 :: INFO <module> :: 		 17 patches of 640x640 (normal tissue).
# 2023-08-22 15:22:06,931 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-08-22 15:22:06,932 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:22:45,776 :: INFO <module> :: Processing tma 'TCGA-CN-6017-01Z-00-DX1.690fa1af-4b51-41c8-a52d-bd1341f990e9_1.png'
# 2023-08-22 15:22:49,446 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:22:49,447 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 15:22:49,448 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 15:22:49,449 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:23:28,230 :: INFO <module> :: Processing tma 'TCGA-CN-6018-01Z-00-DX1.77855643-92a9-40a7-b4a8-0e32b89fc597_0.png'
# 2023-08-22 15:23:31,423 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:23:31,424 :: INFO <module> :: 		 19 patches of 640x640 (normal tissue).
# 2023-08-22 15:23:31,425 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-08-22 15:23:31,426 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:24:06,507 :: INFO <module> :: Processing tma 'TCGA-CN-6018-01Z-00-DX1.77855643-92a9-40a7-b4a8-0e32b89fc597_1.png'
# 2023-08-22 15:24:09,852 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:24:09,853 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 15:24:09,854 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 15:24:09,855 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:24:45,938 :: INFO <module> :: Processing tma 'TCGA-CN-6019-01Z-00-DX1.0a01c44a-b7f4-427e-9854-fe2f0db631ab_0.png'
# 2023-08-22 15:24:49,381 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:24:49,382 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 15:24:49,383 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 15:24:49,384 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:25:26,277 :: INFO <module> :: Processing tma 'TCGA-CN-6019-01Z-00-DX1.0a01c44a-b7f4-427e-9854-fe2f0db631ab_1.png'
# 2023-08-22 15:25:30,123 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:25:30,124 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 15:25:30,124 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 15:25:30,125 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:26:11,600 :: INFO <module> :: Processing tma 'TCGA-CN-6020-01Z-00-DX1.910f4ce3-873f-4712-b896-789d764513a7_0.png'
# 2023-08-22 15:26:15,719 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:26:15,722 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 15:26:15,724 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 15:26:15,725 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:26:56,107 :: INFO <module> :: Processing tma 'TCGA-CN-6020-01Z-00-DX1.910f4ce3-873f-4712-b896-789d764513a7_1.png'
# 2023-08-22 15:26:59,952 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:26:59,952 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 15:26:59,953 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 15:26:59,955 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:27:41,014 :: INFO <module> :: Processing tma 'TCGA-CN-6021-01Z-00-DX1.613eb0f9-f1ca-49a9-9bb8-7fdbb29d7665_0.png'
# 2023-08-22 15:27:44,703 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:27:44,704 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 15:27:44,705 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 15:27:44,706 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:28:22,175 :: INFO <module> :: Processing tma 'TCGA-CN-6021-01Z-00-DX1.613eb0f9-f1ca-49a9-9bb8-7fdbb29d7665_1.png'
# 2023-08-22 15:28:25,360 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:28:25,361 :: INFO <module> :: 		 17 patches of 640x640 (normal tissue).
# 2023-08-22 15:28:25,362 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-08-22 15:28:25,363 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:29:00,697 :: INFO <module> :: Processing tma 'TCGA-CN-6022-01Z-00-DX1.46951ba2-f656-41b9-95c7-a3026ddbd562_0.png'
# 2023-08-22 15:29:04,001 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:29:04,001 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 15:29:04,003 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 15:29:04,003 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:29:41,334 :: INFO <module> :: Processing tma 'TCGA-CN-6022-01Z-00-DX1.46951ba2-f656-41b9-95c7-a3026ddbd562_1.png'
# 2023-08-22 15:29:44,824 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:29:44,825 :: INFO <module> :: 		 1 patches of 640x640 (normal tissue).
# 2023-08-22 15:29:44,826 :: INFO <module> :: 		 44 patches of 640x640 (tumor tissue).
# 2023-08-22 15:29:44,827 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:30:27,872 :: INFO <module> :: Processing tma 'TCGA-CN-6023-01Z-00-DX1.abfbc2c7-109b-4b72-8645-8e4135d00306_0.png'
# 2023-08-22 15:30:31,441 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:30:31,443 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 15:30:31,444 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 15:30:31,444 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:31:12,677 :: INFO <module> :: Processing tma 'TCGA-CN-6023-01Z-00-DX1.abfbc2c7-109b-4b72-8645-8e4135d00306_1.png'
# 2023-08-22 15:31:16,325 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:31:16,326 :: INFO <module> :: 		 16 patches of 640x640 (normal tissue).
# 2023-08-22 15:31:16,327 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-08-22 15:31:16,328 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:31:55,552 :: INFO <module> :: Processing tma 'TCGA-CN-6024-01Z-00-DX1.c5791a72-1ded-4723-a33a-68da0685c80b_0.png'
# 2023-08-22 15:31:59,737 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:31:59,738 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 15:31:59,739 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 15:31:59,740 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:32:39,160 :: INFO <module> :: Processing tma 'TCGA-CN-6024-01Z-00-DX1.c5791a72-1ded-4723-a33a-68da0685c80b_1.png'
# 2023-08-22 15:32:42,236 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:32:42,237 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 15:32:42,238 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 15:32:42,240 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:33:24,269 :: INFO <module> :: Processing tma 'TCGA-CN-6988-01Z-00-DX1.1fc4c572-3495-4f5a-9f1a-60c04096d188_0.png'
# 2023-08-22 15:33:27,442 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:33:27,443 :: INFO <module> :: 		 19 patches of 640x640 (normal tissue).
# 2023-08-22 15:33:27,444 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-08-22 15:33:27,445 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:34:06,615 :: INFO <module> :: Processing tma 'TCGA-CN-6988-01Z-00-DX1.1fc4c572-3495-4f5a-9f1a-60c04096d188_1.png'
# 2023-08-22 15:34:09,778 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:34:09,779 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 15:34:09,780 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 15:34:09,781 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:34:47,150 :: INFO <module> :: Processing tma 'TCGA-CN-6989-01Z-00-DX1.dd68e391-1d00-4bfc-9be9-ff5024bea237_0.png'
# 2023-08-22 15:34:50,582 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:34:50,583 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 15:34:50,585 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 15:34:50,585 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:35:29,945 :: INFO <module> :: Processing tma 'TCGA-CN-6989-01Z-00-DX1.dd68e391-1d00-4bfc-9be9-ff5024bea237_1.png'
# 2023-08-22 15:35:33,569 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:35:33,570 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 15:35:33,571 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 15:35:33,572 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:36:14,497 :: INFO <module> :: Processing tma 'TCGA-CN-6994-01Z-00-DX1.0aa71a4c-25e5-417d-86cf-ce2756e3dd8a_0.png'
# 2023-08-22 15:36:18,764 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:36:18,765 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 15:36:18,766 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 15:36:18,767 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:36:58,712 :: INFO <module> :: Processing tma 'TCGA-CN-6994-01Z-00-DX1.0aa71a4c-25e5-417d-86cf-ce2756e3dd8a_1.png'
# 2023-08-22 15:37:02,177 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:37:02,178 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 15:37:02,179 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 15:37:02,180 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:37:41,581 :: INFO <module> :: Processing tma 'TCGA-CN-6996-01Z-00-DX1.b3a1162b-9adb-4fb2-b472-5b9781b9364d_0.png'
# 2023-08-22 15:37:44,801 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:37:44,802 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 15:37:44,802 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 15:37:44,803 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:38:23,193 :: INFO <module> :: Processing tma 'TCGA-CN-6996-01Z-00-DX1.b3a1162b-9adb-4fb2-b472-5b9781b9364d_1.png'
# 2023-08-22 15:38:26,423 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:38:26,424 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 15:38:26,425 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 15:38:26,425 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:39:04,714 :: INFO <module> :: Processing tma 'TCGA-CN-6997-01Z-00-DX1.7c1686d4-7c15-4332-b962-b36b499dee85_0.png'
# 2023-08-22 15:39:07,884 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:39:07,884 :: INFO <module> :: 		 14 patches of 640x640 (normal tissue).
# 2023-08-22 15:39:07,885 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-08-22 15:39:07,886 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:39:43,794 :: INFO <module> :: Processing tma 'TCGA-CN-6997-01Z-00-DX1.7c1686d4-7c15-4332-b962-b36b499dee85_1.png'
# 2023-08-22 15:39:46,982 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:39:46,983 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 15:39:46,984 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 15:39:46,986 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:40:23,451 :: INFO <module> :: Processing tma 'TCGA-CN-6998-01Z-00-DX1.5780b8b9-0a1f-4330-889c-b345b29396b2_0.png'
# 2023-08-22 15:40:26,756 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:40:26,757 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 15:40:26,758 :: INFO <module> :: 		 43 patches of 640x640 (tumor tissue).
# 2023-08-22 15:40:26,758 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:41:03,183 :: INFO <module> :: Processing tma 'TCGA-CN-6998-01Z-00-DX1.5780b8b9-0a1f-4330-889c-b345b29396b2_1.png'
# 2023-08-22 15:41:06,552 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:41:06,553 :: INFO <module> :: 		 36 patches of 640x640 (normal tissue).
# 2023-08-22 15:41:06,554 :: INFO <module> :: 		 9 patches of 640x640 (tumor tissue).
# 2023-08-22 15:41:06,555 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:41:41,316 :: INFO <module> :: training images
# 2023-08-22 15:41:41,320 :: INFO <module> :: Processing tma 'TCGA-4P-AA8J-01Z-00-DX1.5B44796F-D099-4076-9CAF-B40C2B83F432_0.png'
# 2023-08-22 15:41:44,933 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:41:44,933 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 15:41:44,935 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 15:41:44,935 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:42:25,855 :: INFO <module> :: Processing tma 'TCGA-4P-AA8J-01Z-00-DX1.5B44796F-D099-4076-9CAF-B40C2B83F432_1.png'
# 2023-08-22 15:42:29,281 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:42:29,283 :: INFO <module> :: 		 4 patches of 640x640 (normal tissue).
# 2023-08-22 15:42:29,284 :: INFO <module> :: 		 41 patches of 640x640 (tumor tissue).
# 2023-08-22 15:42:29,285 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:43:08,032 :: INFO <module> :: Processing tma 'TCGA-BA-4074-01Z-00-DX1.937DC1B1-C9A4-4E67-B5FD-A0C0C60D2628_0.png'
# 2023-08-22 15:43:11,792 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:43:11,793 :: INFO <module> :: 		 16 patches of 640x640 (normal tissue).
# 2023-08-22 15:43:11,794 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-08-22 15:43:11,795 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:43:50,503 :: INFO <module> :: Processing tma 'TCGA-BA-4074-01Z-00-DX1.937DC1B1-C9A4-4E67-B5FD-A0C0C60D2628_1.png'
# 2023-08-22 15:43:54,243 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:43:54,244 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 15:43:54,245 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 15:43:54,246 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:44:32,561 :: INFO <module> :: Processing tma 'TCGA-BA-4075-01Z-00-DX1.15BAC45A-F648-47AD-85C9-0CCC6504846E_0.png'
# 2023-08-22 15:44:36,282 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 15:44:36,283 :: INFO <module> :: 		 16 patches of 640x640 (normal tissue).
# 2023-08-22 15:44:36,285 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-08-22 15:44:36,287 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 15:45:14,997 :: INFO <module> :: Processing tma 'TCGA-BA-4075-01Z-00-DX1.15BAC45A-F648-47AD-85C9-0CCC6504846E_1.png'
# ...
# 2023-08-22 16:21:39,268 :: INFO <module> :: 		 0 patches of 640x640 (background).
# 2023-08-22 16:21:40,500 :: INFO <module> :: Processing tma 'TCGA-BB-7861-01Z-00-DX1.efdd186f-1bbf-4e43-9875-9458cebcd0dd_1.png'
# 2023-08-22 16:21:40,701 :: INFO <module> :: 	 4 patches of 640x640 size.
# 2023-08-22 16:21:40,702 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 16:21:40,702 :: INFO <module> :: 		 2 patches of 640x640 (tumor tissue).
# 2023-08-22 16:21:40,703 :: INFO <module> :: 		 0 patches of 640x640 (background).
# 2023-08-22 16:21:41,478 :: INFO <module> :: Processing tma 'TCGA-BB-7862-01Z-00-DX1.13b1af78-0930-44ac-b060-a83613095918_0.png'
# 2023-08-22 16:21:45,256 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:21:45,257 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 16:21:45,258 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 16:21:45,259 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:22:23,462 :: INFO <module> :: Processing tma 'TCGA-BB-7862-01Z-00-DX1.13b1af78-0930-44ac-b060-a83613095918_1.png'
# 2023-08-22 16:22:27,277 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:22:27,278 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 16:22:27,280 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 16:22:27,282 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:23:06,352 :: INFO <module> :: Processing tma 'TCGA-BB-7863-01Z-00-DX1.f7662dec-5c02-4b33-91e4-b6f0b76d8498_0.png'
# 2023-08-22 16:23:10,156 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:23:10,157 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 16:23:10,158 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 16:23:10,159 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:23:48,608 :: INFO <module> :: Processing tma 'TCGA-BB-7863-01Z-00-DX1.f7662dec-5c02-4b33-91e4-b6f0b76d8498_1.png'
# 2023-08-22 16:23:52,445 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:23:52,447 :: INFO <module> :: 		 20 patches of 640x640 (normal tissue).
# 2023-08-22 16:23:52,448 :: INFO <module> :: 		 25 patches of 640x640 (tumor tissue).
# 2023-08-22 16:23:52,449 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:24:30,736 :: INFO <module> :: Processing tma 'TCGA-BB-7864-01Z-00-DX1.a8e9cdba-2026-4290-8e49-36086b65e806_0.png'
# 2023-08-22 16:24:34,427 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:24:34,428 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 16:24:34,429 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 16:24:34,429 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:25:16,022 :: INFO <module> :: Processing tma 'TCGA-BB-7864-01Z-00-DX1.a8e9cdba-2026-4290-8e49-36086b65e806_1.png'
# 2023-08-22 16:25:19,493 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:25:19,494 :: INFO <module> :: 		 8 patches of 640x640 (normal tissue).
# 2023-08-22 16:25:19,495 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-08-22 16:25:19,495 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:26:00,649 :: INFO <module> :: Processing tma 'TCGA-BB-7866-01Z-00-DX1.144872E0-8C08-42CC-ACDD-45D28F35517D_0.png'
# 2023-08-22 16:26:04,461 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:26:04,462 :: INFO <module> :: 		 25 patches of 640x640 (normal tissue).
# 2023-08-22 16:26:04,464 :: INFO <module> :: 		 20 patches of 640x640 (tumor tissue).
# 2023-08-22 16:26:04,465 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:26:42,288 :: INFO <module> :: Processing tma 'TCGA-BB-7866-01Z-00-DX1.144872E0-8C08-42CC-ACDD-45D28F35517D_1.png'
# 2023-08-22 16:26:46,168 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:26:46,169 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 16:26:46,170 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 16:26:46,171 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:27:25,699 :: INFO <module> :: Processing tma 'TCGA-BB-7870-01Z-00-DX1.6b49c1c8-19c4-4e0c-b4b5-f7e9e1ba782c_0.png'
# 2023-08-22 16:27:29,434 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:27:29,435 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 16:27:29,436 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 16:27:29,436 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:28:04,644 :: INFO <module> :: Processing tma 'TCGA-BB-7870-01Z-00-DX1.6b49c1c8-19c4-4e0c-b4b5-f7e9e1ba782c_1.png'
# 2023-08-22 16:28:07,830 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:28:07,830 :: INFO <module> :: 		 5 patches of 640x640 (normal tissue).
# 2023-08-22 16:28:07,831 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-08-22 16:28:07,832 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:28:43,562 :: INFO <module> :: Processing tma 'TCGA-BB-7871-01Z-00-DX1.c062435e-5f17-48d0-af06-dd0253ddcf75_0.png'
# 2023-08-22 16:28:46,729 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:28:46,730 :: INFO <module> :: 		 15 patches of 640x640 (normal tissue).
# 2023-08-22 16:28:46,731 :: INFO <module> :: 		 20 patches of 640x640 (tumor tissue).
# 2023-08-22 16:28:46,732 :: INFO <module> :: 		 14 patches of 640x640 (background).
# 2023-08-22 16:29:11,541 :: INFO <module> :: Processing tma 'TCGA-BB-7871-01Z-00-DX1.c062435e-5f17-48d0-af06-dd0253ddcf75_1.png'
# 2023-08-22 16:29:11,722 :: INFO <module> :: 	 4 patches of 640x640 size.
# 2023-08-22 16:29:11,723 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 16:29:11,724 :: INFO <module> :: 		 2 patches of 640x640 (tumor tissue).
# 2023-08-22 16:29:11,724 :: INFO <module> :: 		 0 patches of 640x640 (background).
# 2023-08-22 16:29:12,350 :: INFO <module> :: Processing tma 'TCGA-BB-7872-01Z-00-DX1.0117273b-4be0-4f73-b408-88721fa52e67_0.png'
# 2023-08-22 16:29:13,096 :: INFO <module> :: 	 16 patches of 640x640 size.
# 2023-08-22 16:29:13,097 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-08-22 16:29:13,098 :: INFO <module> :: 		 15 patches of 640x640 (tumor tissue).
# 2023-08-22 16:29:13,098 :: INFO <module> :: 		 1 patches of 640x640 (background).
# 2023-08-22 16:29:19,393 :: INFO <module> :: Processing tma 'TCGA-BB-7872-01Z-00-DX1.0117273b-4be0-4f73-b408-88721fa52e67_1.png'
# 2023-08-22 16:29:20,196 :: INFO <module> :: 	 16 patches of 640x640 size.
# 2023-08-22 16:29:20,197 :: INFO <module> :: 		 2 patches of 640x640 (normal tissue).
# 2023-08-22 16:29:20,198 :: INFO <module> :: 		 13 patches of 640x640 (tumor tissue).
# 2023-08-22 16:29:20,199 :: INFO <module> :: 		 1 patches of 640x640 (background).
# 2023-08-22 16:29:26,274 :: INFO <module> :: Processing tma 'TCGA-BB-8596-01Z-00-DX1.F354D65B-F1F9-447C-8C6A-519140FC4549_0.png'
# 2023-08-22 16:29:29,269 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:29:29,270 :: INFO <module> :: 		 14 patches of 640x640 (normal tissue).
# 2023-08-22 16:29:29,271 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-08-22 16:29:29,271 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:30:06,303 :: INFO <module> :: Processing tma 'TCGA-BB-8596-01Z-00-DX1.F354D65B-F1F9-447C-8C6A-519140FC4549_1.png'
# 2023-08-22 16:30:09,451 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:30:09,452 :: INFO <module> :: 		 15 patches of 640x640 (normal tissue).
# 2023-08-22 16:30:09,453 :: INFO <module> :: 		 30 patches of 640x640 (tumor tissue).
# 2023-08-22 16:30:09,454 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:30:46,744 :: INFO <module> :: Processing tma 'TCGA-BB-8601-01Z-00-DX1.A226FE85-28D7-44C1-8330-CC687677EC59_0.png'
# 2023-08-22 16:30:49,855 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:30:49,855 :: INFO <module> :: 		 21 patches of 640x640 (normal tissue).
# 2023-08-22 16:30:49,856 :: INFO <module> :: 		 24 patches of 640x640 (tumor tissue).
# 2023-08-22 16:30:49,858 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:31:25,205 :: INFO <module> :: Processing tma 'TCGA-BB-8601-01Z-00-DX1.A226FE85-28D7-44C1-8330-CC687677EC59_1.png'
# 2023-08-22 16:31:28,164 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:31:28,165 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 16:31:28,166 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 16:31:28,166 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:32:05,394 :: INFO <module> :: Processing tma 'TCGA-BB-A5HU-01Z-00-DX1.B9A51FFE-D49C-478E-82C9-ABB7AA43EA4E_0.png'
# 2023-08-22 16:32:08,486 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:32:08,487 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 16:32:08,488 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 16:32:08,489 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:32:45,445 :: INFO <module> :: Processing tma 'TCGA-BB-A5HU-01Z-00-DX1.B9A51FFE-D49C-478E-82C9-ABB7AA43EA4E_1.png'
# 2023-08-22 16:32:48,632 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:32:48,633 :: INFO <module> :: 		 16 patches of 640x640 (normal tissue).
# 2023-08-22 16:32:48,633 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-08-22 16:32:48,635 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:33:24,705 :: INFO <module> :: Processing tma 'TCGA-BB-A5HY-01Z-00-DX1.0BDC44E8-17E5-4907-9C9B-417FF335AEC8_0.png'
# 2023-08-22 16:33:27,795 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:33:27,796 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 16:33:27,796 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 16:33:27,797 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:34:03,608 :: INFO <module> :: Processing tma 'TCGA-BB-A5HY-01Z-00-DX1.0BDC44E8-17E5-4907-9C9B-417FF335AEC8_1.png'
# 2023-08-22 16:34:06,714 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:34:06,715 :: INFO <module> :: 		 22 patches of 640x640 (normal tissue).
# 2023-08-22 16:34:06,716 :: INFO <module> :: 		 23 patches of 640x640 (tumor tissue).
# 2023-08-22 16:34:06,717 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:34:41,140 :: INFO <module> :: Processing tma 'TCGA-BB-A5HZ-01Z-00-DX1.4EAE9F9E-7118-4BDB-9FC9-344BC5E2AF46_0.png'
# 2023-08-22 16:34:44,339 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:34:44,340 :: INFO <module> :: 		 12 patches of 640x640 (normal tissue).
# 2023-08-22 16:34:44,341 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-08-22 16:34:44,341 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:35:21,589 :: INFO <module> :: Processing tma 'TCGA-BB-A5HZ-01Z-00-DX1.4EAE9F9E-7118-4BDB-9FC9-344BC5E2AF46_1.png'
# 2023-08-22 16:35:24,880 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:35:24,881 :: INFO <module> :: 		 3 patches of 640x640 (normal tissue).
# 2023-08-22 16:35:24,882 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-08-22 16:35:24,883 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:36:02,684 :: INFO <module> :: Processing tma 'TCGA-BB-A6UM-01Z-00-DX1.403D4D0A-83F4-4D2F-9CBB-C7A1470AC565_0.png'
# 2023-08-22 16:36:05,787 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:36:05,788 :: INFO <module> :: 		 9 patches of 640x640 (normal tissue).
# 2023-08-22 16:36:05,789 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-08-22 16:36:05,790 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:36:42,075 :: INFO <module> :: Processing tma 'TCGA-BB-A6UM-01Z-00-DX1.403D4D0A-83F4-4D2F-9CBB-C7A1470AC565_1.png'
# 2023-08-22 16:36:45,240 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:36:45,241 :: INFO <module> :: 		 10 patches of 640x640 (normal tissue).
# 2023-08-22 16:36:45,242 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-08-22 16:36:45,243 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:37:21,721 :: INFO <module> :: Processing tma 'TCGA-BB-A6UO-01Z-00-DX1.11D049DC-EFC3-47EB-B390-A694BFD304A2_0.png'
# 2023-08-22 16:37:24,853 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:37:24,854 :: INFO <module> :: 		 12 patches of 640x640 (normal tissue).
# 2023-08-22 16:37:24,854 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-08-22 16:37:24,855 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:38:01,391 :: INFO <module> :: Processing tma 'TCGA-BB-A6UO-01Z-00-DX1.11D049DC-EFC3-47EB-B390-A694BFD304A2_1.png'
# 2023-08-22 16:38:04,563 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:38:04,564 :: INFO <module> :: 		 18 patches of 640x640 (normal tissue).
# 2023-08-22 16:38:04,565 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-08-22 16:38:04,566 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:38:40,482 :: INFO <module> :: Processing tma 'TCGA-C9-A47Z-01Z-00-DX1.7999EE26-CB1A-464D-8E88-F3122F8D1A41_0.png'
# 2023-08-22 16:38:43,711 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:38:43,712 :: INFO <module> :: 		 7 patches of 640x640 (normal tissue).
# 2023-08-22 16:38:43,712 :: INFO <module> :: 		 38 patches of 640x640 (tumor tissue).
# 2023-08-22 16:38:43,713 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:39:22,419 :: INFO <module> :: Processing tma 'TCGA-C9-A47Z-01Z-00-DX1.7999EE26-CB1A-464D-8E88-F3122F8D1A41_1.png'
# 2023-08-22 16:39:26,149 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:39:26,150 :: INFO <module> :: 		 12 patches of 640x640 (normal tissue).
# 2023-08-22 16:39:26,151 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-08-22 16:39:26,152 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:40:03,882 :: INFO <module> :: Processing tma 'TCGA-C9-A480-01Z-00-DX1.24793EF4-30F2-46DF-A64E-52021F132EE0_0.png'
# 2023-08-22 16:40:07,350 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:40:07,351 :: INFO <module> :: 		 20 patches of 640x640 (normal tissue).
# 2023-08-22 16:40:07,352 :: INFO <module> :: 		 25 patches of 640x640 (tumor tissue).
# 2023-08-22 16:40:07,353 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:40:41,969 :: INFO <module> :: Processing tma 'TCGA-C9-A480-01Z-00-DX1.24793EF4-30F2-46DF-A64E-52021F132EE0_1.png'
# 2023-08-22 16:40:45,400 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:40:45,401 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 16:40:45,402 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 16:40:45,402 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:41:20,314 :: INFO <module> :: Processing tma 'TCGA-CN-4722-01Z-00-DX1.cf599bd8-c285-4f44-82d0-64f4b453d5e5_0.png'
# 2023-08-22 16:41:23,661 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:41:23,662 :: INFO <module> :: 		 11 patches of 640x640 (normal tissue).
# 2023-08-22 16:41:23,664 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-08-22 16:41:23,665 :: INFO <module> :: 		 4 patches of 640x640 (background).
# 2023-08-22 16:41:59,795 :: INFO <module> :: Processing tma 'TCGA-CN-4722-01Z-00-DX1.cf599bd8-c285-4f44-82d0-64f4b453d5e5_1.png'
# 2023-08-22 16:42:03,093 :: INFO <module> :: 	 49 patches of 640x640 size.
# 2023-08-22 16:42:03,094 :: INFO <module> :: 		 13 patches of 640x640 (normal tissue).
# 2023-08-22 16:42:03,095 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-08-22 16:42:03,095 :: INFO <module> :: 		 4 patches of 640x640 (background).

# %% [markdown]
# # Generate the 512x512 dataset

# %%
from orca_dataloader import *

magnification=0.625
scale = get_scale_by_magnification(magnification)
tile_size=20
tile_size_original = int(scale * tile_size)


cls = "tumor"
dataset_types = ["training", "testing"]
for dataset_type in sorted(dataset_types):
    
    logger.info("{} images".format(dataset_type))
    
    orca_dir = "../../datasets/ORCA"
    annotations_dir = "{}/{}/lesion_annotations".format(orca_dir, dataset_type)
    tma_images_dir = "{}/{}/{}/wsi".format(orca_dir, dataset_type, cls)
    
    orca_512x512_dir = "../../datasets/ORCA_512x512"
    resized_annotations_dir = "{}/{}/lesion_annotations".format(orca_512x512_dir, dataset_type)
    resized_tma_images_dir = "{}/{}/{}/tma".format(orca_512x512_dir, dataset_type, cls)
    
    for r, d, f in sorted(os.walk(tma_images_dir)):
        for tma_file in sorted(f):
            
            tma_image_file = "{}/{}".format(r, tma_file)
            tma_image_number = tma_file.replace(".png", "")
            
            file_is_png = tma_image_file.lower().endswith('.png')
            if file_is_png:

                logger.info("Processing tma '{}'".format(tma_file))
                
                # tumor annotations mask
                annotation_file = "{}/{}_mask.png".format(annotations_dir, tma_image_number)
                tma_mask_pil = load_pil_image(annotation_file, gray=True)
                
                # tumor tma image
                tma_image_pil = load_pil_image(tma_image_file, gray=False)
                
                #print("{}/{}_mask.png".format(resized_annotations_dir, tma_image_number))
                resized_tma_mask_np = image_resize(pil_to_np(tma_mask_pil), width=512, height=512)
                np_tumor_mask = np.zeros((512, 512), dtype=bool)
                np_tumor_mask[resized_tma_mask_np == 255] = True
                pil_tumor_mask = np_to_pil(np_tumor_mask)
                pil_tumor_mask.save("{}/{}_mask.png".format(resized_annotations_dir, tma_image_number))
                
                #print("{}/{}".format(resized_tma_images_dir, tma_file))
                resized_tma_image_np = image_resize(pil_to_np(tma_image_pil), width=512, height=512)
                np_to_pil(resized_tma_image_np).save("{}/{}".format(resized_tma_images_dir, tma_file))
# Out:
# 2023-08-22 17:25:44,718 :: INFO <module> :: testing images
# 2023-08-22 17:25:44,723 :: INFO <module> :: Processing tma 'TCGA-CN-4723-01Z-00-DX1.13483e7b-9322-4d39-8cd6-91e898bf2ee9_0.png'
# 2023-08-22 17:25:46,597 :: INFO <module> :: Processing tma 'TCGA-CN-4723-01Z-00-DX1.13483e7b-9322-4d39-8cd6-91e898bf2ee9_1.png'
# 2023-08-22 17:25:48,151 :: INFO <module> :: Processing tma 'TCGA-CN-4725-01Z-00-DX1.fe518acf-cceb-4be4-b01a-63d66248d6d4_0.png'
# 2023-08-22 17:25:49,597 :: INFO <module> :: Processing tma 'TCGA-CN-4725-01Z-00-DX1.fe518acf-cceb-4be4-b01a-63d66248d6d4_1.png'
# 2023-08-22 17:25:51,605 :: INFO <module> :: Processing tma 'TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_0.png'
# 2023-08-22 17:25:53,235 :: INFO <module> :: Processing tma 'TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_1.png'
# 2023-08-22 17:25:55,124 :: INFO <module> :: Processing tma 'TCGA-CN-4727-01Z-00-DX1.bee9d488-0f05-4579-8c34-aa4197972bb1_0.png'
# 2023-08-22 17:25:56,663 :: INFO <module> :: Processing tma 'TCGA-CN-4727-01Z-00-DX1.bee9d488-0f05-4579-8c34-aa4197972bb1_1.png'
# 2023-08-22 17:25:58,260 :: INFO <module> :: Processing tma 'TCGA-CN-4728-01Z-00-DX1.69fc04ce-cc6b-4c63-9322-b5ffb0056828_0.png'
# 2023-08-22 17:25:59,893 :: INFO <module> :: Processing tma 'TCGA-CN-4728-01Z-00-DX1.69fc04ce-cc6b-4c63-9322-b5ffb0056828_1.png'
# 2023-08-22 17:26:01,406 :: INFO <module> :: Processing tma 'TCGA-CN-4729-01Z-00-DX1.fd5f9170-c35b-4095-aff3-4c95921e0e68_0.png'
# 2023-08-22 17:26:02,892 :: INFO <module> :: Processing tma 'TCGA-CN-4729-01Z-00-DX1.fd5f9170-c35b-4095-aff3-4c95921e0e68_1.png'
# 2023-08-22 17:26:04,457 :: INFO <module> :: Processing tma 'TCGA-CN-4730-01Z-00-DX1.a76280e8-6591-4d51-afc9-2f01e87346ab_0.png'
# 2023-08-22 17:26:05,918 :: INFO <module> :: Processing tma 'TCGA-CN-4730-01Z-00-DX1.a76280e8-6591-4d51-afc9-2f01e87346ab_1.png'
# 2023-08-22 17:26:07,408 :: INFO <module> :: Processing tma 'TCGA-CN-4731-01Z-00-DX1.07b0bf3b-77f3-4471-a63c-1afc54714a60_0.png'
# 2023-08-22 17:26:09,347 :: INFO <module> :: Processing tma 'TCGA-CN-4731-01Z-00-DX1.07b0bf3b-77f3-4471-a63c-1afc54714a60_1.png'
# 2023-08-22 17:26:10,929 :: INFO <module> :: Processing tma 'TCGA-CN-4733-01Z-00-DX1.03cccb3f-c551-450f-b00a-f808a237db0b_0.png'
# 2023-08-22 17:26:12,403 :: INFO <module> :: Processing tma 'TCGA-CN-4733-01Z-00-DX1.03cccb3f-c551-450f-b00a-f808a237db0b_1.png'
# 2023-08-22 17:26:13,967 :: INFO <module> :: Processing tma 'TCGA-CN-4734-01Z-00-DX1.9cd35e43-7132-478a-9d08-a88d150b7127_0.png'
# 2023-08-22 17:26:15,569 :: INFO <module> :: Processing tma 'TCGA-CN-4734-01Z-00-DX1.9cd35e43-7132-478a-9d08-a88d150b7127_1.png'
# 2023-08-22 17:26:17,160 :: INFO <module> :: Processing tma 'TCGA-CN-4735-01Z-00-DX1.b7d37666-bd65-4d3b-826b-97e560444956_0.png'
# 2023-08-22 17:26:18,855 :: INFO <module> :: Processing tma 'TCGA-CN-4735-01Z-00-DX1.b7d37666-bd65-4d3b-826b-97e560444956_1.png'
# 2023-08-22 17:26:20,495 :: INFO <module> :: Processing tma 'TCGA-CN-4736-01Z-00-DX1.883fda2c-82bd-46c1-b220-b9961d8700cc_0.png'
# 2023-08-22 17:26:22,043 :: INFO <module> :: Processing tma 'TCGA-CN-4736-01Z-00-DX1.883fda2c-82bd-46c1-b220-b9961d8700cc_1.png'
# 2023-08-22 17:26:23,712 :: INFO <module> :: Processing tma 'TCGA-CN-4737-01Z-00-DX1.15951662-62c1-49e1-94ea-1f4ebad55507_0.png'
# 2023-08-22 17:26:25,292 :: INFO <module> :: Processing tma 'TCGA-CN-4737-01Z-00-DX1.15951662-62c1-49e1-94ea-1f4ebad55507_1.png'
# 2023-08-22 17:26:26,927 :: INFO <module> :: Processing tma 'TCGA-CN-4738-01Z-00-DX1.9c456d54-0bde-4f04-ba53-17c09e692491_0.png'
# 2023-08-22 17:26:28,652 :: INFO <module> :: Processing tma 'TCGA-CN-4738-01Z-00-DX1.9c456d54-0bde-4f04-ba53-17c09e692491_1.png'
# 2023-08-22 17:26:30,198 :: INFO <module> :: Processing tma 'TCGA-CN-4739-01Z-00-DX1.e50266c3-606e-4103-a029-021246d4d1df_0.png'
# 2023-08-22 17:26:31,879 :: INFO <module> :: Processing tma 'TCGA-CN-4739-01Z-00-DX1.e50266c3-606e-4103-a029-021246d4d1df_1.png'
# 2023-08-22 17:26:33,617 :: INFO <module> :: Processing tma 'TCGA-CN-4740-01Z-00-DX1.f7b9f5ec-cb4e-4604-9d64-2bdc20ac5bec_0.png'
# 2023-08-22 17:26:35,293 :: INFO <module> :: Processing tma 'TCGA-CN-4740-01Z-00-DX1.f7b9f5ec-cb4e-4604-9d64-2bdc20ac5bec_1.png'
# 2023-08-22 17:26:36,837 :: INFO <module> :: Processing tma 'TCGA-CN-4741-01Z-00-DX1.6adfce37-b5b0-44ff-834e-85059eec24c0_0.png'
# 2023-08-22 17:26:38,385 :: INFO <module> :: Processing tma 'TCGA-CN-4741-01Z-00-DX1.6adfce37-b5b0-44ff-834e-85059eec24c0_1.png'
# 2023-08-22 17:26:40,029 :: INFO <module> :: Processing tma 'TCGA-CN-4742-01Z-00-DX1.d03eaeac-cc05-4b13-962e-d4d10617d692_0.png'
# 2023-08-22 17:26:41,620 :: INFO <module> :: Processing tma 'TCGA-CN-4742-01Z-00-DX1.d03eaeac-cc05-4b13-962e-d4d10617d692_1.png'
# 2023-08-22 17:26:43,146 :: INFO <module> :: Processing tma 'TCGA-CN-5355-01Z-00-DX1.8fb23e44-fc59-4191-b825-cc021807a338_0.png'
# 2023-08-22 17:26:44,894 :: INFO <module> :: Processing tma 'TCGA-CN-5355-01Z-00-DX1.8fb23e44-fc59-4191-b825-cc021807a338_1.png'
# 2023-08-22 17:26:46,475 :: INFO <module> :: Processing tma 'TCGA-CN-5356-01Z-00-DX1.53360c41-d0d2-465e-8b53-ccd1a2ce248f_0.png'
# 2023-08-22 17:26:48,190 :: INFO <module> :: Processing tma 'TCGA-CN-5356-01Z-00-DX1.53360c41-d0d2-465e-8b53-ccd1a2ce248f_1.png'
# 2023-08-22 17:26:49,831 :: INFO <module> :: Processing tma 'TCGA-CN-5358-01Z-00-DX1.6554cdc1-7d01-4310-a60a-79b8ed7a8679_0.png'
# 2023-08-22 17:26:51,638 :: INFO <module> :: Processing tma 'TCGA-CN-5358-01Z-00-DX1.6554cdc1-7d01-4310-a60a-79b8ed7a8679_1.png'
# 2023-08-22 17:26:53,208 :: INFO <module> :: Processing tma 'TCGA-CN-5359-01Z-00-DX1.30a19cad-c2b0-4c5f-bd5d-89aa8ac2bb91_0.png'
# 2023-08-22 17:26:54,913 :: INFO <module> :: Processing tma 'TCGA-CN-5359-01Z-00-DX1.30a19cad-c2b0-4c5f-bd5d-89aa8ac2bb91_1.png'
# 2023-08-22 17:26:56,436 :: INFO <module> :: Processing tma 'TCGA-CN-5360-01Z-00-DX1.d3657b07-9ea0-41fc-b858-c9a1497340c8_0.png'
# 2023-08-22 17:26:57,987 :: INFO <module> :: Processing tma 'TCGA-CN-5360-01Z-00-DX1.d3657b07-9ea0-41fc-b858-c9a1497340c8_1.png'
# 2023-08-22 17:26:59,802 :: INFO <module> :: Processing tma 'TCGA-CN-5361-01Z-00-DX1.719cf77b-0dd4-4419-be8f-0d3dadedd7cb_0.png'
# 2023-08-22 17:27:01,401 :: INFO <module> :: Processing tma 'TCGA-CN-5361-01Z-00-DX1.719cf77b-0dd4-4419-be8f-0d3dadedd7cb_1.png'
# 2023-08-22 17:27:02,852 :: INFO <module> :: Processing tma 'TCGA-CN-5363-01Z-00-DX1.bd9c87d4-de64-4932-a90f-95888150d780_0.png'
# 2023-08-22 17:27:04,352 :: INFO <module> :: Processing tma 'TCGA-CN-5363-01Z-00-DX1.bd9c87d4-de64-4932-a90f-95888150d780_1.png'
# 2023-08-22 17:27:05,696 :: INFO <module> :: Processing tma 'TCGA-CN-5364-01Z-00-DX1.caeed5d0-cd48-40f3-b81b-099637341563_0.png'
# 2023-08-22 17:27:07,276 :: INFO <module> :: Processing tma 'TCGA-CN-5364-01Z-00-DX1.caeed5d0-cd48-40f3-b81b-099637341563_1.png'
# 2023-08-22 17:27:08,779 :: INFO <module> :: Processing tma 'TCGA-CN-5365-01Z-00-DX1.26a33bd0-1eb3-4774-8be6-bf8501f4a9f9_0.png'
# 2023-08-22 17:27:10,364 :: INFO <module> :: Processing tma 'TCGA-CN-5365-01Z-00-DX1.26a33bd0-1eb3-4774-8be6-bf8501f4a9f9_1.png'
# 2023-08-22 17:27:11,826 :: INFO <module> :: Processing tma 'TCGA-CN-5366-01Z-00-DX1.dcc14c44-6dd1-48a1-a21c-736c6b9551e1_0.png'
# 2023-08-22 17:27:13,279 :: INFO <module> :: Processing tma 'TCGA-CN-5366-01Z-00-DX1.dcc14c44-6dd1-48a1-a21c-736c6b9551e1_1.png'
# 2023-08-22 17:27:14,837 :: INFO <module> :: Processing tma 'TCGA-CN-5367-01Z-00-DX1.5b09e54e-4140-4709-bc60-e201f9a72b24_0.png'
# 2023-08-22 17:27:16,430 :: INFO <module> :: Processing tma 'TCGA-CN-5367-01Z-00-DX1.5b09e54e-4140-4709-bc60-e201f9a72b24_1.png'
# 2023-08-22 17:27:17,941 :: INFO <module> :: Processing tma 'TCGA-CN-5369-01Z-00-DX1.be289b39-c6c2-43a6-8feb-75ad5829ec81_0.png'
# 2023-08-22 17:27:19,220 :: INFO <module> :: Processing tma 'TCGA-CN-5369-01Z-00-DX1.be289b39-c6c2-43a6-8feb-75ad5829ec81_1.png'
# 2023-08-22 17:27:20,677 :: INFO <module> :: Processing tma 'TCGA-CN-5373-01Z-00-DX1.c423a74f-cdb6-41b1-9483-be854827434e_0.png'
# 2023-08-22 17:27:22,175 :: INFO <module> :: Processing tma 'TCGA-CN-5373-01Z-00-DX1.c423a74f-cdb6-41b1-9483-be854827434e_1.png'
# 2023-08-22 17:27:23,748 :: INFO <module> :: Processing tma 'TCGA-CN-5374-01Z-00-DX1.027c681b-d8d8-47fd-b0f8-917d6ddb3b83_0.png'
# 2023-08-22 17:27:25,420 :: INFO <module> :: Processing tma 'TCGA-CN-5374-01Z-00-DX1.027c681b-d8d8-47fd-b0f8-917d6ddb3b83_1.png'
# 2023-08-22 17:27:26,893 :: INFO <module> :: Processing tma 'TCGA-CN-6010-01Z-00-DX1.8a82a2d0-c687-4b75-922f-b5b64b5a99df_0.png'
# 2023-08-22 17:27:28,184 :: INFO <module> :: Processing tma 'TCGA-CN-6010-01Z-00-DX1.8a82a2d0-c687-4b75-922f-b5b64b5a99df_1.png'
# 2023-08-22 17:27:29,437 :: INFO <module> :: Processing tma 'TCGA-CN-6011-01Z-00-DX1.a3a73ffe-06b8-42ea-820b-9c2824d96585_0.png'
# 2023-08-22 17:27:30,798 :: INFO <module> :: Processing tma 'TCGA-CN-6011-01Z-00-DX1.a3a73ffe-06b8-42ea-820b-9c2824d96585_1.png'
# 2023-08-22 17:27:32,239 :: INFO <module> :: Processing tma 'TCGA-CN-6012-01Z-00-DX1.bd9283bb-47c7-41ab-996a-f3f5070cfc73_0.png'
# 2023-08-22 17:27:33,545 :: INFO <module> :: Processing tma 'TCGA-CN-6012-01Z-00-DX1.bd9283bb-47c7-41ab-996a-f3f5070cfc73_1.png'
# 2023-08-22 17:27:34,847 :: INFO <module> :: Processing tma 'TCGA-CN-6016-01Z-00-DX1.737054ae-50f4-42c4-b79c-c462220b12f3_0.png'
# 2023-08-22 17:27:36,130 :: INFO <module> :: Processing tma 'TCGA-CN-6016-01Z-00-DX1.737054ae-50f4-42c4-b79c-c462220b12f3_1.png'
# 2023-08-22 17:27:37,418 :: INFO <module> :: Processing tma 'TCGA-CN-6017-01Z-00-DX1.690fa1af-4b51-41c8-a52d-bd1341f990e9_0.png'
# 2023-08-22 17:27:38,907 :: INFO <module> :: Processing tma 'TCGA-CN-6017-01Z-00-DX1.690fa1af-4b51-41c8-a52d-bd1341f990e9_1.png'
# 2023-08-22 17:27:40,316 :: INFO <module> :: Processing tma 'TCGA-CN-6018-01Z-00-DX1.77855643-92a9-40a7-b4a8-0e32b89fc597_0.png'
# 2023-08-22 17:27:42,168 :: INFO <module> :: Processing tma 'TCGA-CN-6018-01Z-00-DX1.77855643-92a9-40a7-b4a8-0e32b89fc597_1.png'
# 2023-08-22 17:27:44,008 :: INFO <module> :: Processing tma 'TCGA-CN-6019-01Z-00-DX1.0a01c44a-b7f4-427e-9854-fe2f0db631ab_0.png'
# 2023-08-22 17:27:45,708 :: INFO <module> :: Processing tma 'TCGA-CN-6019-01Z-00-DX1.0a01c44a-b7f4-427e-9854-fe2f0db631ab_1.png'
# 2023-08-22 17:27:47,136 :: INFO <module> :: Processing tma 'TCGA-CN-6020-01Z-00-DX1.910f4ce3-873f-4712-b896-789d764513a7_0.png'
# 2023-08-22 17:27:48,442 :: INFO <module> :: Processing tma 'TCGA-CN-6020-01Z-00-DX1.910f4ce3-873f-4712-b896-789d764513a7_1.png'
# 2023-08-22 17:27:49,892 :: INFO <module> :: Processing tma 'TCGA-CN-6021-01Z-00-DX1.613eb0f9-f1ca-49a9-9bb8-7fdbb29d7665_0.png'
# 2023-08-22 17:27:51,501 :: INFO <module> :: Processing tma 'TCGA-CN-6021-01Z-00-DX1.613eb0f9-f1ca-49a9-9bb8-7fdbb29d7665_1.png'
# 2023-08-22 17:27:52,884 :: INFO <module> :: Processing tma 'TCGA-CN-6022-01Z-00-DX1.46951ba2-f656-41b9-95c7-a3026ddbd562_0.png'
# 2023-08-22 17:27:54,259 :: INFO <module> :: Processing tma 'TCGA-CN-6022-01Z-00-DX1.46951ba2-f656-41b9-95c7-a3026ddbd562_1.png'
# 2023-08-22 17:27:55,631 :: INFO <module> :: Processing tma 'TCGA-CN-6023-01Z-00-DX1.abfbc2c7-109b-4b72-8645-8e4135d00306_0.png'
# 2023-08-22 17:27:57,016 :: INFO <module> :: Processing tma 'TCGA-CN-6023-01Z-00-DX1.abfbc2c7-109b-4b72-8645-8e4135d00306_1.png'
# 2023-08-22 17:27:58,490 :: INFO <module> :: Processing tma 'TCGA-CN-6024-01Z-00-DX1.c5791a72-1ded-4723-a33a-68da0685c80b_0.png'
# 2023-08-22 17:27:59,908 :: INFO <module> :: Processing tma 'TCGA-CN-6024-01Z-00-DX1.c5791a72-1ded-4723-a33a-68da0685c80b_1.png'
# 2023-08-22 17:28:01,242 :: INFO <module> :: Processing tma 'TCGA-CN-6988-01Z-00-DX1.1fc4c572-3495-4f5a-9f1a-60c04096d188_0.png'
# 2023-08-22 17:28:02,507 :: INFO <module> :: Processing tma 'TCGA-CN-6988-01Z-00-DX1.1fc4c572-3495-4f5a-9f1a-60c04096d188_1.png'
# 2023-08-22 17:28:03,806 :: INFO <module> :: Processing tma 'TCGA-CN-6989-01Z-00-DX1.dd68e391-1d00-4bfc-9be9-ff5024bea237_0.png'
# 2023-08-22 17:28:05,146 :: INFO <module> :: Processing tma 'TCGA-CN-6989-01Z-00-DX1.dd68e391-1d00-4bfc-9be9-ff5024bea237_1.png'
# 2023-08-22 17:28:06,502 :: INFO <module> :: Processing tma 'TCGA-CN-6994-01Z-00-DX1.0aa71a4c-25e5-417d-86cf-ce2756e3dd8a_0.png'
# 2023-08-22 17:28:08,055 :: INFO <module> :: Processing tma 'TCGA-CN-6994-01Z-00-DX1.0aa71a4c-25e5-417d-86cf-ce2756e3dd8a_1.png'
# 2023-08-22 17:28:09,329 :: INFO <module> :: Processing tma 'TCGA-CN-6996-01Z-00-DX1.b3a1162b-9adb-4fb2-b472-5b9781b9364d_0.png'
# 2023-08-22 17:28:11,128 :: INFO <module> :: Processing tma 'TCGA-CN-6996-01Z-00-DX1.b3a1162b-9adb-4fb2-b472-5b9781b9364d_1.png'
# 2023-08-22 17:28:12,562 :: INFO <module> :: Processing tma 'TCGA-CN-6997-01Z-00-DX1.7c1686d4-7c15-4332-b962-b36b499dee85_0.png'
# 2023-08-22 17:28:13,982 :: INFO <module> :: Processing tma 'TCGA-CN-6997-01Z-00-DX1.7c1686d4-7c15-4332-b962-b36b499dee85_1.png'
# 2023-08-22 17:28:15,681 :: INFO <module> :: Processing tma 'TCGA-CN-6998-01Z-00-DX1.5780b8b9-0a1f-4330-889c-b345b29396b2_0.png'
# 2023-08-22 17:28:17,451 :: INFO <module> :: Processing tma 'TCGA-CN-6998-01Z-00-DX1.5780b8b9-0a1f-4330-889c-b345b29396b2_1.png'
# 2023-08-22 17:28:19,622 :: INFO <module> :: training images
# 2023-08-22 17:28:19,628 :: INFO <module> :: Processing tma 'TCGA-4P-AA8J-01Z-00-DX1.5B44796F-D099-4076-9CAF-B40C2B83F432_0.png'
# 2023-08-22 17:28:21,254 :: INFO <module> :: Processing tma 'TCGA-4P-AA8J-01Z-00-DX1.5B44796F-D099-4076-9CAF-B40C2B83F432_1.png'
# 2023-08-22 17:28:23,450 :: INFO <module> :: Processing tma 'TCGA-BA-4074-01Z-00-DX1.937DC1B1-C9A4-4E67-B5FD-A0C0C60D2628_0.png'
# 2023-08-22 17:28:25,541 :: INFO <module> :: Processing tma 'TCGA-BA-4074-01Z-00-DX1.937DC1B1-C9A4-4E67-B5FD-A0C0C60D2628_1.png'
# 2023-08-22 17:28:27,135 :: INFO <module> :: Processing tma 'TCGA-BA-4075-01Z-00-DX1.15BAC45A-F648-47AD-85C9-0CCC6504846E_0.png'
# 2023-08-22 17:28:28,428 :: INFO <module> :: Processing tma 'TCGA-BA-4075-01Z-00-DX1.15BAC45A-F648-47AD-85C9-0CCC6504846E_1.png'
# 2023-08-22 17:28:29,747 :: INFO <module> :: Processing tma 'TCGA-BA-4077-01Z-00-DX1.547A89DF-9628-4594-BEB7-20EA7C5B5A5E_0.png'
# 2023-08-22 17:28:31,030 :: INFO <module> :: Processing tma 'TCGA-BA-4077-01Z-00-DX1.547A89DF-9628-4594-BEB7-20EA7C5B5A5E_1.png'
# 2023-08-22 17:28:32,285 :: INFO <module> :: Processing tma 'TCGA-BA-4078-01Z-00-DX1.B190F43D-3313-496B-BEF7-3798A5DE5E55_0.png'
# 2023-08-22 17:28:33,563 :: INFO <module> :: Processing tma 'TCGA-BA-4078-01Z-00-DX1.B190F43D-3313-496B-BEF7-3798A5DE5E55_1.png'
# 2023-08-22 17:28:34,822 :: INFO <module> :: Processing tma 'TCGA-BA-5149-01Z-00-DX1.ecb9aaa2-68b0-47e2-b96f-8cd78bf0a6fb_0.png'
# 2023-08-22 17:28:36,509 :: INFO <module> :: Processing tma 'TCGA-BA-5149-01Z-00-DX1.ecb9aaa2-68b0-47e2-b96f-8cd78bf0a6fb_1.png'
# 2023-08-22 17:28:37,725 :: INFO <module> :: Processing tma 'TCGA-BA-5151-01Z-00-DX1.32EE476B-128D-4153-A57C-CFA823B993A2_0.png'
# 2023-08-22 17:28:38,093 :: INFO <module> :: Processing tma 'TCGA-BA-5151-01Z-00-DX1.32EE476B-128D-4153-A57C-CFA823B993A2_1.png'
# 2023-08-22 17:28:38,448 :: INFO <module> :: Processing tma 'TCGA-BA-5152-01Z-00-DX1.d85d709e-8627-46d4-8558-ce5bdad2d552_0.png'
# 2023-08-22 17:28:39,869 :: INFO <module> :: Processing tma 'TCGA-BA-5152-01Z-00-DX1.d85d709e-8627-46d4-8558-ce5bdad2d552_1.png'
# 2023-08-22 17:28:41,310 :: INFO <module> :: Processing tma 'TCGA-BA-5153-01Z-00-DX1.045011D8-DF25-4B13-BF92-188D5EBE96CF_1.png'
# 2023-08-22 17:28:41,701 :: INFO <module> :: Processing tma 'TCGA-BA-5555-01Z-00-DX1.cffe9b77-36d4-49f1-86f8-90686c695985_0.png'
# 2023-08-22 17:28:43,290 :: INFO <module> :: Processing tma 'TCGA-BA-5555-01Z-00-DX1.cffe9b77-36d4-49f1-86f8-90686c695985_1.png'
# 2023-08-22 17:28:44,802 :: INFO <module> :: Processing tma 'TCGA-BA-5556-01Z-00-DX1.6941a8fa-2f68-41d8-8661-82601570d901_0.png'
# 2023-08-22 17:28:46,183 :: INFO <module> :: Processing tma 'TCGA-BA-5556-01Z-00-DX1.6941a8fa-2f68-41d8-8661-82601570d901_1.png'
# 2023-08-22 17:28:47,580 :: INFO <module> :: Processing tma 'TCGA-BA-5558-01Z-00-DX1.a134a6eb-86d6-4619-a90b-1d471e8aa348_0.png'
# 2023-08-22 17:28:49,170 :: INFO <module> :: Processing tma 'TCGA-BA-5558-01Z-00-DX1.a134a6eb-86d6-4619-a90b-1d471e8aa348_1.png'
# 2023-08-22 17:28:50,985 :: INFO <module> :: Processing tma 'TCGA-BA-5559-01Z-00-DX1.2ef4e82a-fec2-4382-966c-ad991e5b2787_0.png'
# 2023-08-22 17:28:52,428 :: INFO <module> :: Processing tma 'TCGA-BA-5559-01Z-00-DX1.2ef4e82a-fec2-4382-966c-ad991e5b2787_1.png'
# 2023-08-22 17:28:54,312 :: INFO <module> :: Processing tma 'TCGA-BA-6868-01Z-00-DX1.edbca656-6680-4c99-92ef-d7467f42c780_0.png'
# 2023-08-22 17:28:56,154 :: INFO <module> :: Processing tma 'TCGA-BA-6868-01Z-00-DX1.edbca656-6680-4c99-92ef-d7467f42c780_1.png'
# 2023-08-22 17:28:57,674 :: INFO <module> :: Processing tma 'TCGA-BA-6869-01Z-00-DX1.6e58648e-3309-47bb-b2c7-b71bcd9dc69b_0.png'
# 2023-08-22 17:28:59,115 :: INFO <module> :: Processing tma 'TCGA-BA-6869-01Z-00-DX1.6e58648e-3309-47bb-b2c7-b71bcd9dc69b_1.png'
# 2023-08-22 17:29:00,536 :: INFO <module> :: Processing tma 'TCGA-BA-6871-01Z-00-DX1.4d9ca329-f8d5-4c31-a20f-9d4fba728326_0.png'
# 2023-08-22 17:29:01,816 :: INFO <module> :: Processing tma 'TCGA-BA-6871-01Z-00-DX1.4d9ca329-f8d5-4c31-a20f-9d4fba728326_1.png'
# 2023-08-22 17:29:03,122 :: INFO <module> :: Processing tma 'TCGA-BA-6872-01Z-00-DX1.F99F6394-D319-4599-B124-D2A6692FA096_0.png'
# 2023-08-22 17:29:04,523 :: INFO <module> :: Processing tma 'TCGA-BA-6872-01Z-00-DX1.F99F6394-D319-4599-B124-D2A6692FA096_1.png'
# 2023-08-22 17:29:05,899 :: INFO <module> :: Processing tma 'TCGA-BA-6873-01Z-00-DX1.F0A84DE2-7A08-44D5-9FD1-A284F55AA8C1_0.png'
# 2023-08-22 17:29:07,231 :: INFO <module> :: Processing tma 'TCGA-BA-7269-01Z-00-DX1.A759601F-7513-47C6-B590-4ADAA3484CD9_0.png'
# 2023-08-22 17:29:08,547 :: INFO <module> :: Processing tma 'TCGA-BA-7269-01Z-00-DX1.A759601F-7513-47C6-B590-4ADAA3484CD9_1.png'
# 2023-08-22 17:29:09,921 :: INFO <module> :: Processing tma 'TCGA-BA-A6D8-01Z-00-DX1.0198253B-84AC-484E-9A58-F7CF8AEBE922_0.png'
# 2023-08-22 17:29:11,269 :: INFO <module> :: Processing tma 'TCGA-BA-A6D8-01Z-00-DX1.0198253B-84AC-484E-9A58-F7CF8AEBE922_1.png'
# 2023-08-22 17:29:12,636 :: INFO <module> :: Processing tma 'TCGA-BA-A6DA-01Z-00-DX1.8BFA179A-8E8A-45DC-A036-77A7D6ABB7EA_0.png'
# 2023-08-22 17:29:13,917 :: INFO <module> :: Processing tma 'TCGA-BA-A6DA-01Z-00-DX1.8BFA179A-8E8A-45DC-A036-77A7D6ABB7EA_1.png'
# 2023-08-22 17:29:15,174 :: INFO <module> :: Processing tma 'TCGA-BA-A6DB-01Z-00-DX1.6EC4113A-D48B-4F83-84EF-1A811C67FDFE_0.png'
# 2023-08-22 17:29:16,506 :: INFO <module> :: Processing tma 'TCGA-BA-A6DB-01Z-00-DX1.6EC4113A-D48B-4F83-84EF-1A811C67FDFE_1.png'
# 2023-08-22 17:29:17,877 :: INFO <module> :: Processing tma 'TCGA-BA-A6DE-01Z-00-DX1.3279D372-4A92-4CFA-9E52-19197934378D_0.png'
# 2023-08-22 17:29:19,169 :: INFO <module> :: Processing tma 'TCGA-BA-A6DE-01Z-00-DX1.3279D372-4A92-4CFA-9E52-19197934378D_1.png'
# 2023-08-22 17:29:20,459 :: INFO <module> :: Processing tma 'TCGA-BA-A6DF-01Z-00-DX1.AAA638F5-C794-441B-A034-30AD8CC72573_0.png'
# 2023-08-22 17:29:21,920 :: INFO <module> :: Processing tma 'TCGA-BA-A6DG-01Z-00-DX1.B227E4F2-2F78-4AD7-BD85-2A77701BACBA_0.png'
# 2023-08-22 17:29:23,154 :: INFO <module> :: Processing tma 'TCGA-BA-A6DG-01Z-00-DX1.B227E4F2-2F78-4AD7-BD85-2A77701BACBA_1.png'
# 2023-08-22 17:29:24,424 :: INFO <module> :: Processing tma 'TCGA-BA-A6DI-01Z-00-DX1.4EB42174-5219-43A3-AD93-64446DCE37CF_0.png'
# 2023-08-22 17:29:25,731 :: INFO <module> :: Processing tma 'TCGA-BA-A6DI-01Z-00-DX1.4EB42174-5219-43A3-AD93-64446DCE37CF_1.png'
# 2023-08-22 17:29:27,028 :: INFO <module> :: Processing tma 'TCGA-BA-A8YP-01Z-00-DX1.03B95E63-2639-49F6-B8DD-AC2C2FA872B1_0.png'
# 2023-08-22 17:29:28,313 :: INFO <module> :: Processing tma 'TCGA-BA-A8YP-01Z-00-DX1.03B95E63-2639-49F6-B8DD-AC2C2FA872B1_1.png'
# 2023-08-22 17:29:29,617 :: INFO <module> :: Processing tma 'TCGA-BB-4217-01Z-00-DX1.E351C8DB-F6CB-4327-9FEC-B9001E70C913_1.png'
# 2023-08-22 17:29:30,975 :: INFO <module> :: Processing tma 'TCGA-BB-4223-01Z-00-DX1.8806b83e-910f-4ee8-aa83-f84e3d13155f_0.png'
# 2023-08-22 17:29:32,362 :: INFO <module> :: Processing tma 'TCGA-BB-4223-01Z-00-DX1.8806b83e-910f-4ee8-aa83-f84e3d13155f_1.png'
# 2023-08-22 17:29:33,908 :: INFO <module> :: Processing tma 'TCGA-BB-4224-01Z-00-DX1.ebdb44ef-4266-40b7-bc1b-e197c9813868_0.png'
# 2023-08-22 17:29:35,262 :: INFO <module> :: Processing tma 'TCGA-BB-4227-01Z-00-DX1.7475866c-90bb-4f62-b44e-adccc731cad8_0.png'
# 2023-08-22 17:29:36,639 :: INFO <module> :: Processing tma 'TCGA-BB-4227-01Z-00-DX1.7475866c-90bb-4f62-b44e-adccc731cad8_1.png'
# 2023-08-22 17:29:37,929 :: INFO <module> :: Processing tma 'TCGA-BB-4228-01Z-00-DX1.170b1b9a-05ac-4115-965e-56c2af944f1f_0.png'
# 2023-08-22 17:29:39,729 :: INFO <module> :: Processing tma 'TCGA-BB-4228-01Z-00-DX1.170b1b9a-05ac-4115-965e-56c2af944f1f_1.png'
# 2023-08-22 17:29:41,206 :: INFO <module> :: Processing tma 'TCGA-BB-7861-01Z-00-DX1.efdd186f-1bbf-4e43-9875-9458cebcd0dd_0.png'
# 2023-08-22 17:29:41,351 :: INFO <module> :: Processing tma 'TCGA-BB-7861-01Z-00-DX1.efdd186f-1bbf-4e43-9875-9458cebcd0dd_1.png'
# 2023-08-22 17:29:41,504 :: INFO <module> :: Processing tma 'TCGA-BB-7862-01Z-00-DX1.13b1af78-0930-44ac-b060-a83613095918_0.png'
# 2023-08-22 17:29:43,098 :: INFO <module> :: Processing tma 'TCGA-BB-7862-01Z-00-DX1.13b1af78-0930-44ac-b060-a83613095918_1.png'
# 2023-08-22 17:29:44,659 :: INFO <module> :: Processing tma 'TCGA-BB-7863-01Z-00-DX1.f7662dec-5c02-4b33-91e4-b6f0b76d8498_0.png'
# 2023-08-22 17:29:46,166 :: INFO <module> :: Processing tma 'TCGA-BB-7863-01Z-00-DX1.f7662dec-5c02-4b33-91e4-b6f0b76d8498_1.png'
# 2023-08-22 17:29:47,510 :: INFO <module> :: Processing tma 'TCGA-BB-7864-01Z-00-DX1.a8e9cdba-2026-4290-8e49-36086b65e806_0.png'
# 2023-08-22 17:29:48,806 :: INFO <module> :: Processing tma 'TCGA-BB-7864-01Z-00-DX1.a8e9cdba-2026-4290-8e49-36086b65e806_1.png'
# 2023-08-22 17:29:50,245 :: INFO <module> :: Processing tma 'TCGA-BB-7866-01Z-00-DX1.144872E0-8C08-42CC-ACDD-45D28F35517D_0.png'
# 2023-08-22 17:29:51,623 :: INFO <module> :: Processing tma 'TCGA-BB-7866-01Z-00-DX1.144872E0-8C08-42CC-ACDD-45D28F35517D_1.png'
# 2023-08-22 17:29:53,057 :: INFO <module> :: Processing tma 'TCGA-BB-7870-01Z-00-DX1.6b49c1c8-19c4-4e0c-b4b5-f7e9e1ba782c_0.png'
# 2023-08-22 17:29:55,459 :: INFO <module> :: Processing tma 'TCGA-BB-7870-01Z-00-DX1.6b49c1c8-19c4-4e0c-b4b5-f7e9e1ba782c_1.png'
# 2023-08-22 17:29:56,834 :: INFO <module> :: Processing tma 'TCGA-BB-7871-01Z-00-DX1.c062435e-5f17-48d0-af06-dd0253ddcf75_0.png'
# 2023-08-22 17:29:58,092 :: INFO <module> :: Processing tma 'TCGA-BB-7871-01Z-00-DX1.c062435e-5f17-48d0-af06-dd0253ddcf75_1.png'
# 2023-08-22 17:29:58,271 :: INFO <module> :: Processing tma 'TCGA-BB-7872-01Z-00-DX1.0117273b-4be0-4f73-b408-88721fa52e67_0.png'
# 2023-08-22 17:29:58,608 :: INFO <module> :: Processing tma 'TCGA-BB-7872-01Z-00-DX1.0117273b-4be0-4f73-b408-88721fa52e67_1.png'
# 2023-08-22 17:29:58,984 :: INFO <module> :: Processing tma 'TCGA-BB-8596-01Z-00-DX1.F354D65B-F1F9-447C-8C6A-519140FC4549_0.png'
# 2023-08-22 17:30:00,295 :: INFO <module> :: Processing tma 'TCGA-BB-8596-01Z-00-DX1.F354D65B-F1F9-447C-8C6A-519140FC4549_1.png'
# 2023-08-22 17:30:01,756 :: INFO <module> :: Processing tma 'TCGA-BB-8601-01Z-00-DX1.A226FE85-28D7-44C1-8330-CC687677EC59_0.png'
# 2023-08-22 17:30:03,080 :: INFO <module> :: Processing tma 'TCGA-BB-8601-01Z-00-DX1.A226FE85-28D7-44C1-8330-CC687677EC59_1.png'
# 2023-08-22 17:30:04,368 :: INFO <module> :: Processing tma 'TCGA-BB-A5HU-01Z-00-DX1.B9A51FFE-D49C-478E-82C9-ABB7AA43EA4E_0.png'
# 2023-08-22 17:30:05,718 :: INFO <module> :: Processing tma 'TCGA-BB-A5HU-01Z-00-DX1.B9A51FFE-D49C-478E-82C9-ABB7AA43EA4E_1.png'
# 2023-08-22 17:30:07,042 :: INFO <module> :: Processing tma 'TCGA-BB-A5HY-01Z-00-DX1.0BDC44E8-17E5-4907-9C9B-417FF335AEC8_0.png'
# 2023-08-22 17:30:08,398 :: INFO <module> :: Processing tma 'TCGA-BB-A5HY-01Z-00-DX1.0BDC44E8-17E5-4907-9C9B-417FF335AEC8_1.png'
# 2023-08-22 17:30:09,761 :: INFO <module> :: Processing tma 'TCGA-BB-A5HZ-01Z-00-DX1.4EAE9F9E-7118-4BDB-9FC9-344BC5E2AF46_0.png'
# 2023-08-22 17:30:11,342 :: INFO <module> :: Processing tma 'TCGA-BB-A5HZ-01Z-00-DX1.4EAE9F9E-7118-4BDB-9FC9-344BC5E2AF46_1.png'
# 2023-08-22 17:30:12,578 :: INFO <module> :: Processing tma 'TCGA-BB-A6UM-01Z-00-DX1.403D4D0A-83F4-4D2F-9CBB-C7A1470AC565_0.png'
# 2023-08-22 17:30:13,852 :: INFO <module> :: Processing tma 'TCGA-BB-A6UM-01Z-00-DX1.403D4D0A-83F4-4D2F-9CBB-C7A1470AC565_1.png'
# 2023-08-22 17:30:15,310 :: INFO <module> :: Processing tma 'TCGA-BB-A6UO-01Z-00-DX1.11D049DC-EFC3-47EB-B390-A694BFD304A2_0.png'
# 2023-08-22 17:30:16,589 :: INFO <module> :: Processing tma 'TCGA-BB-A6UO-01Z-00-DX1.11D049DC-EFC3-47EB-B390-A694BFD304A2_1.png'
# 2023-08-22 17:30:17,785 :: INFO <module> :: Processing tma 'TCGA-C9-A47Z-01Z-00-DX1.7999EE26-CB1A-464D-8E88-F3122F8D1A41_0.png'
# 2023-08-22 17:30:19,083 :: INFO <module> :: Processing tma 'TCGA-C9-A47Z-01Z-00-DX1.7999EE26-CB1A-464D-8E88-F3122F8D1A41_1.png'
# 2023-08-22 17:30:20,388 :: INFO <module> :: Processing tma 'TCGA-C9-A480-01Z-00-DX1.24793EF4-30F2-46DF-A64E-52021F132EE0_0.png'
# 2023-08-22 17:30:21,794 :: INFO <module> :: Processing tma 'TCGA-C9-A480-01Z-00-DX1.24793EF4-30F2-46DF-A64E-52021F132EE0_1.png'
# 2023-08-22 17:30:23,169 :: INFO <module> :: Processing tma 'TCGA-CN-4722-01Z-00-DX1.cf599bd8-c285-4f44-82d0-64f4b453d5e5_0.png'
# 2023-08-22 17:30:24,564 :: INFO <module> :: Processing tma 'TCGA-CN-4722-01Z-00-DX1.cf599bd8-c285-4f44-82d0-64f4b453d5e5_1.png'
